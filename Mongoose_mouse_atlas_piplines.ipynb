# %% [markdown]
# # GenKI ko DBit-seq

# %% [markdown]
# ## set up

# %%
# Install GenKI and torch_geometric as a prerequisite
! pip install git+https://github.com/yjgeno/GenKI.git
! pip install torch_geometric

# Install STRINGdb and Networkx for network biology models
! pip install stringdb
! pip install networkx pandas
# Out:
# Collecting git+https://github.com/yjgeno/GenKI.git
#   Cloning https://github.com/yjgeno/GenKI.git to /tmp/pip-req-build-juoyakl9
#   Running command git clone --filter=blob:none --quiet https://github.com/yjgeno/GenKI.git /tmp/pip-req-build-juoyakl9
#   Resolved https://github.com/yjgeno/GenKI.git to commit 6d69789b89859eda75ac75dfb1cc00ef190ada41
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: anndata==0.8.0 in /usr/local/lib/python3.10/dist-packages (from GenKI==0.0.1.dev0) (0.8.0)
# Requirement already satisfied: matplotlib~=3.5.1 in /usr/local/lib/python3.10/dist-packages (from GenKI==0.0.1.dev0) (3.5.3)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from GenKI==0.0.1.dev0) (1.24.4)
# Requirement already satisfied: pandas~=1.4.2 in /usr/local/lib/python3.10/dist-packages (from GenKI==0.0.1.dev0) (1.4.4)
# Requirement already satisfied: ray>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from GenKI==0.0.1.dev0) (2.39.0)
# Requirement already satisfied: scanpy==1.9.1 in /usr/local/lib/python3.10/dist-packages (from GenKI==0.0.1.dev0) (1.9.1)
# Requirement already satisfied: scipy~=1.8.0 in /usr/local/lib/python3.10/dist-packages (from GenKI==0.0.1.dev0) (1.8.1)
# Requirement already satisfied: statsmodels~=0.13.2 in /usr/local/lib/python3.10/dist-packages (from GenKI==0.0.1.dev0) (0.13.5)
# Requirement already satisfied: scikit_learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from GenKI==0.0.1.dev0) (1.5.2)
# Requirement already satisfied: tqdm~=4.64.0 in /usr/local/lib/python3.10/dist-packages (from GenKI==0.0.1.dev0) (4.64.1)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.10/dist-packages (from anndata==0.8.0->GenKI==0.0.1.dev0) (3.12.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from anndata==0.8.0->GenKI==0.0.1.dev0) (8.4.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from anndata==0.8.0->GenKI==0.0.1.dev0) (24.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from scanpy==1.9.1->GenKI==0.0.1.dev0) (0.13.2)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy==1.9.1->GenKI==0.0.1.dev0) (1.0.1)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.10/dist-packages (from scanpy==1.9.1->GenKI==0.0.1.dev0) (3.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy==1.9.1->GenKI==0.0.1.dev0) (1.4.2)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.10/dist-packages (from scanpy==1.9.1->GenKI==0.0.1.dev0) (0.60.0)
# Requirement already satisfied: umap-learn>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from scanpy==1.9.1->GenKI==0.0.1.dev0) (0.5.7)
# Requirement already satisfied: session-info in /usr/local/lib/python3.10/dist-packages (from scanpy==1.9.1->GenKI==0.0.1.dev0) (1.0.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->GenKI==0.0.1.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->GenKI==0.0.1.dev0) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->GenKI==0.0.1.dev0) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->GenKI==0.0.1.dev0) (11.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->GenKI==0.0.1.dev0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.5.1->GenKI==0.0.1.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.4.2->GenKI==0.0.1.dev0) (2024.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray>=1.11.0->GenKI==0.0.1.dev0) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray>=1.11.0->GenKI==0.0.1.dev0) (3.16.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray>=1.11.0->GenKI==0.0.1.dev0) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray>=1.11.0->GenKI==0.0.1.dev0) (1.1.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray>=1.11.0->GenKI==0.0.1.dev0) (4.25.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray>=1.11.0->GenKI==0.0.1.dev0) (6.0.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray>=1.11.0->GenKI==0.0.1.dev0) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray>=1.11.0->GenKI==0.0.1.dev0) (1.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray>=1.11.0->GenKI==0.0.1.dev0) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>=1.0.2->GenKI==0.0.1.dev0) (3.5.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.41.0->scanpy==1.9.1->GenKI==0.0.1.dev0) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.5.1->GenKI==0.0.1.dev0) (1.16.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.3.10->scanpy==1.9.1->GenKI==0.0.1.dev0) (0.5.13)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=1.11.0->GenKI==0.0.1.dev0) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=1.11.0->GenKI==0.0.1.dev0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=1.11.0->GenKI==0.0.1.dev0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=1.11.0->GenKI==0.0.1.dev0) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=1.11.0->GenKI==0.0.1.dev0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=1.11.0->GenKI==0.0.1.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=1.11.0->GenKI==0.0.1.dev0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=1.11.0->GenKI==0.0.1.dev0) (2024.8.30)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.10/dist-packages (from session-info->scanpy==1.9.1->GenKI==0.0.1.dev0) (0.11.0)
# Collecting torch_geometric
#   Using cached torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.11.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2024.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.24.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.64.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->torch_geometric) (4.12.2)
# Using cached torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1
# Requirement already satisfied: stringdb in /usr/local/lib/python3.10/dist-packages (0.1.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stringdb) (1.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stringdb) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stringdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stringdb) (2024.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->stringdb) (1.24.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stringdb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stringdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stringdb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stringdb) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->stringdb) (1.16.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.4.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# Restart kernel
import os
os.kill(os.getpid(), 9)

# %%
import os
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
import scanpy as sc

sc.settings.verbosity = 0

# %%
import GenKI as gk
from GenKI.preprocesing import build_adata
from GenKI.dataLoader import DataLoader
from GenKI.train import VGAE_trainer
from GenKI import utils

# %load_ext autoreload
# %autoreload 2

# %%
import stringdb
import networkx as nx

# %%
# Libraries for data wrangling on the adata object
from scipy.sparse import csr_matrix
from scipy.sparse import issparse

# %%
# Download the DBiT-seq dataset suitable for this workshop
# !gdown  1D3AIjshsAiIOktmFrvMgqKO1UKiQSPbu

# Assemble adata object for single-cell analysis
adata = sc.read("DBiTseq_UnitedNet.h5ad")
adata
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1D3AIjshsAiIOktmFrvMgqKO1UKiQSPbu
# To: /content/DBiTseq_UnitedNet.h5ad
# 100% 2.36M/2.36M [00:00<00:00, 75.2MB/s]
# AnnData object with n_obs × n_vars = 936 × 568
#     obs: 'id', 'array_row', 'array_col', 'cell_type', 'batch', 'imagecol', 'imagerow', 'label', 'sample'
#     var: 'gene_ids-0', 'gene_ids-1'
#     obsm: 'spatial'

# %% [markdown]
# ## KO one gene example: Six2

# %%
# Let's commence with creating a digital KO of Six2 expression in the DBiT-seq mouse embryo dataset.
gene_of_interest = "Six2"

# Verify that the gene of interest is part of the rownames in adata.var
if gene_of_interest in adata.var.index:
    print(f"The gene {gene_of_interest} is present in the rownames of adata.var.")
else:
    print(f"The gene {gene_of_interest} is not present in the rownames of adata.var.")
# Out:
# The gene Six2 is present in the rownames of adata.var.

# %%
# adata pre-processing to prepare for input in the GenKI tool
adata.layers["norm"] = adata.X.copy()

# The adata.X should be normalised-scaled AND in sparse matrix format!
if not issparse(adata.X):
    sparse_matrix = csr_matrix(adata.X)
    adata.X = sparse_matrix
    print("Converted adata.X to a sparse matrix.")
else:
    print("adata.X is already a sparse matrix.")
# Out:
# Converted adata.X to a sparse matrix.

# %%
# load data

data_wrapper =  DataLoader(
                adata, # adata object
                target_gene = [gene_of_interest], # KO gene name
                target_cell = None, # obsname for cell type, if none use all
                obs_label = "ident", # colname for genes
                GRN_file_dir = "GRNs", # folder name for GRNs
                rebuild_GRN = True, # whether build GRN by pcNet
                pcNet_name = "DBiTseq_example", # GRN file name
                verbose = True, # whether verbose
                n_cpus = 8, # multiprocessing
                )

data_wt = data_wrapper.load_data()
data_ko = data_wrapper.load_kodata()
# Out:
# use all the cells (936) in adata
# build GRN
# 2024-10-31 06:40:05,213	INFO worker.py:1816 -- Started a local Ray instance.
# ray init, using 8 CPUs
# execution time of making pcNet: 194.29 s
# GRN has been built and saved in "GRNs/DBiTseq_example.npz"
# init completed

# %%
#Changed the hyperparameters to better adapt to the spatial dataset in hand

hyperparams = {
    "epochs": 300,  # Increased epochs for more training
    "lr": 5e-2,  # Adjusted learning rate
    "beta": 5e-4,  # Increased beta for stronger regularization
    "seed": 8096  # Trying a different seed
}


log_dir = None

sensei = VGAE_trainer(
    data_wt,
    epochs=hyperparams["epochs"],
    lr=hyperparams["lr"],
    log_dir=log_dir,
    beta=hyperparams["beta"],
    seed=hyperparams["seed"],
    verbose=False,
)

# %%
# %%timeit
sensei.train()

# %%
sensei.save_model('model_example_DBiTseq')
# Out:
# save model parameters to model/model_example_DBiTseq.th

# %%
# get distance between wt and ko

z_mu_wt, z_std_wt = sensei.get_latent_vars(data_wt)
z_mu_ko, z_std_ko = sensei.get_latent_vars(data_ko)
dis = gk.utils.get_distance(z_mu_ko, z_std_ko, z_mu_wt, z_std_wt, by="KL")
print(dis.shape)
# Out:
# (568,)

# %%
# raw ranked gene list

res_raw = utils.get_generank(data_wt, dis, rank=True)
res_raw.head(10)
# Out:
#                 dis  rank
# Six2    8423.716324     1
# Col3a1    16.065773     2
# Col1a2     8.421597     3
# Vcan       6.678489     4
# Gpc3       6.598462     5
# Lgals1     5.790285     6
# Fbn2       5.741572     7
# Rbp1       5.733980     8
# Col4a1     5.731743     9
# Cxcl12     5.602060    10

# %% [markdown]
# ### Experiment: Try KO all the genes

# %%
# Step 1: Select a placeholder gene (e.g., the first gene in your dataset)
placeholder_gene = adata.var_names[0]

# Step 2: Build the GRN Once using the placeholder gene
data_wrapper = DataLoader(
    adata,
    target_gene=[placeholder_gene],  # Placeholder gene
    target_cell=None,
    obs_label="ident",
    GRN_file_dir="GRNs",
    rebuild_GRN=True,  # Build GRN only once
    pcNet_name="DBiTseq_example",
    verbose=True,
    n_cpus=8,
)
# Out:
# use all the cells (936) in adata
# build GRN
# 2024-10-24 10:07:30,078	INFO worker.py:1816 -- Started a local Ray instance.
# ray init, using 8 CPUs
# execution time of making pcNet: 212.20 s
# GRN has been built and saved in "GRNs/DBiTseq_example.npz"
# init completed

# %%
# Load wild-type data once
data_wt = data_wrapper.load_data()

# Get all genes
all_genes = adata.var.index.tolist()

# Split the genes into batches of 50
batch_size = 50
gene_batches = [all_genes[i:i + batch_size] for i in range(0, len(all_genes), batch_size)]

# Adjust hyperparameters for faster computation
hyperparams = {
    "epochs": 100,  # Reduced epochs for faster training
    "lr": 1e-2,     # Adjusted learning rate
    "beta": 1e-4,   # Regularization parameter
    "seed": 8096,
}

# Initialize a list to store results
results = []

def process_gene(gene):
    # Function to process a single gene

    # Create a new DataLoader instance for this gene
    data_wrapper_gene = DataLoader(
        adata,
        target_gene=[gene],
        target_cell=None,
        obs_label="ident",
        GRN_file_dir="GRNs",
        rebuild_GRN=False,  # GRN already built
        pcNet_name="DBiTseq_example",
        verbose=False,
        n_cpus=1,  # Use one CPU per process to manage resources
    )

    # Load KO data for the current gene
    data_ko = data_wrapper_gene.load_kodata()

    # Initialize the trainer with the same parameters
    sensei = VGAE_trainer(
        data_wt,
        epochs=hyperparams["epochs"],
        lr=hyperparams["lr"],
        beta=hyperparams["beta"],
        seed=hyperparams["seed"],
        verbose=False,
    )

    # Train the model
    sensei.train()

    # Get latent variables
    z_mu_wt, z_std_wt = sensei.get_latent_vars(data_wt)
    z_mu_ko, z_std_ko = sensei.get_latent_vars(data_ko)

    # Compute distance
    dis = gk.utils.get_distance(z_mu_ko, z_std_ko, z_mu_wt, z_std_wt, by="KL")

    # Clean up to free memory
    del data_ko, sensei, z_mu_wt, z_std_wt, z_mu_ko, z_std_ko
    gc.collect()

    return (gene, dis)

# %%
# Loop over gene batches
for batch_num, gene_batch in enumerate(gene_batches):
    print(f"Processing batch {batch_num + 1}/{len(gene_batches)} with {len(gene_batch)} genes")

    # Process genes sequentially within the batch
    for gene in gene_batch:
        print(f"Processing gene: {gene}")
        result = process_gene(gene)
        results.append(result)

    # Optional: Save intermediate results after each batch
    df_intermediate = pd.DataFrame(results, columns=['Gene', 'Distance'])
    df_intermediate.to_csv(f'results_batch_{batch_num + 1}.csv', index=False)

# Step 5: Compile results into a DataFrame (a separate Dataframe for each batch)
df_results = pd.DataFrame(results, columns=['Gene', 'Distance'])

# Rank the genes based on distance
df_results['Rank'] = df_results['Distance'].rank(ascending=False)

# Display top genes
print(df_results.sort_values('Rank').head(10))
# Out:
# Processing batch 1/12 with 50 genes
# Processing gene: 1810037I17Rik
# Processing gene: 2410002F23Rik
# Processing gene: 5730559C18Rik
# Processing gene: Aagab
# Processing gene: Aars2
# Processing gene: Acat1
# Processing gene: Acta2
# Processing gene: Actc1
# Processing gene: Actn1
# Processing gene: Acvr2b
# Processing gene: Adam10
# Processing gene: Adamts1
# Processing gene: Adamts18
# Processing gene: Adamtsl1
# Processing gene: Adgrl2
# Processing gene: Adgrv1
# Processing gene: Afap1
# Processing gene: Aff3
# Processing gene: Afg3l1
# Processing gene: Ahnak
# Processing gene: Akap7
# Processing gene: Aldh1a3
# Processing gene: Alx1
# Processing gene: Alx3
# Processing gene: Amotl1
# Processing gene: Anapc13
# Processing gene: Angptl2
# Processing gene: Ank2
# Processing gene: Ank3
# Processing gene: Ankrd1
# Processing gene: Anp32a
# Processing gene: Anxa2
# Processing gene: Ap1s2
# Processing gene: Ap2s1
# Processing gene: Apod
# Processing gene: Apoe
# Processing gene: Arf5
# Processing gene: Arhgap1
# Processing gene: Arhgap11a
# Processing gene: Arhgap35
# Processing gene: Arx
# Processing gene: Atp1b1
# Processing gene: Bach2
# Processing gene: Barhl2
# Processing gene: Bcl11a
# Processing gene: Bcl11b
# Processing gene: Bex1
# Processing gene: Bicc1
# Processing gene: Bri3
# Processing gene: Btg1
# Processing batch 2/12 with 50 genes
# Processing gene: Bub3
# Processing gene: C130093G08Rik
# Processing gene: C530008M17Rik
# Processing gene: Cadm1
# Processing gene: Cadps
# Processing gene: Camsap1
# Processing gene: Cand2
# Processing gene: Capn6
# Processing gene: Casz1
# Processing gene: Cbl
# Processing gene: Cblb
# Processing gene: Ccdc34
# Processing gene: Ccnt2
# Processing gene: Cd2bp2
# Processing gene: Cd47
# Processing gene: Cd63
# Processing gene: Cd81
# Processing gene: Cdk5r1
# Processing gene: Cds2
# Processing gene: Celsr2
# Processing gene: Cenpb
# Processing gene: Chd3
# Processing gene: Chl1
# Processing gene: Chmp4b
# Processing gene: Cks1b
# Processing gene: Clcn5
# Processing gene: Cldn6
# Processing gene: Cnn1
# Processing gene: Cnn2
# Processing gene: Cnpy1
# Processing gene: Cnr1
# Processing gene: Cntn2
# Processing gene: Cntnap2
# Processing gene: Col11a1
# Processing gene: Col12a1
# Processing gene: Col1a1
# Processing gene: Col1a2
# Processing gene: Col25a1
# Processing gene: Col26a1
# Processing gene: Col2a1
# Processing gene: Col3a1
# Processing gene: Col4a1
# Processing gene: Col4a2
# Processing gene: Col9a1
# Processing gene: Copb2
# Processing gene: Coq4
# Processing gene: Cox17
# Processing gene: Cox5a
# Processing gene: Cpe
# Processing gene: Cplx2
# Processing batch 3/12 with 50 genes
# Processing gene: Cpxm1
# Processing gene: Crabp1
# Processing gene: Crabp2
# Processing gene: Crcp
# Processing gene: Creb3l2
# Processing gene: Crebbp
# Processing gene: Crlf1
# Processing gene: Cryab
# Processing gene: Crym
# Processing gene: Csnk1e
# Processing gene: Ctnnbl1
# Processing gene: Ctsd
# Processing gene: Cxcl12
# Processing gene: Cxxc4
# Processing gene: D930015E06Rik
# Processing gene: Dab2
# Processing gene: Dbx1
# Processing gene: Dclk1
# Processing gene: Dcx
# Processing gene: Ddx1
# Processing gene: Des
# Processing gene: Dhx36
# Processing gene: Dicer1
# Processing gene: Dlk1
# Processing gene: Dlx1
# Processing gene: Dlx2
# Processing gene: Dmrta2
# Processing gene: Dnajc1
# Processing gene: Dnajc19
# Processing gene: Dnajc3
# Processing gene: Dpy19l1
# Processing gene: Dpysl4
# Processing gene: Dpysl5
# Processing gene: Draxin
# Processing gene: Dsp
# Processing gene: Dstn
# Processing gene: Dtl
# Processing gene: Dtx4
# Processing gene: Dtymk
# Processing gene: Dusp6
# Processing gene: Ebf1
# Processing gene: Ebf2
# Processing gene: Echs1
# Processing gene: Edf1
# Processing gene: Ednrb
# Processing gene: Efnb1
# Processing gene: Ehmt2
# Processing gene: Eif2b5
# Processing gene: Eif3d
# Processing gene: Eif4e2
# Processing batch 4/12 with 50 genes
# Processing gene: Eif4g3
# Processing gene: Elavl2
# Processing gene: Elavl3
# Processing gene: Elavl4
# Processing gene: Elk3
# Processing gene: Eml4
# Processing gene: Emx2
# Processing gene: En2
# Processing gene: Enpp2
# Processing gene: Epb41
# Processing gene: Epb41l3
# Processing gene: Epcam
# Processing gene: Epha5
# Processing gene: Epha7
# Processing gene: Epn1
# Processing gene: Ercc5
# Processing gene: Exosc10
# Processing gene: Eya1
# Processing gene: Ezr
# Processing gene: Fabp7
# Processing gene: Fam168b
# Processing gene: Fam192a
# Processing gene: Fbl
# Processing gene: Fbln1
# Processing gene: Fbln2
# Processing gene: Fbn2
# Processing gene: Fbxl2
# Processing gene: Fem1b
# Processing gene: Fezf1
# Processing gene: Fezf2
# Processing gene: Fgf13
# Processing gene: Fgfr1
# Processing gene: Fkbp2
# Processing gene: Fkbp9
# Processing gene: Flrt3
# Processing gene: Fmnl3
# Processing gene: Fndc5
# Processing gene: Foxc1
# Processing gene: Foxg1
# Processing gene: Foxo3
# Processing gene: Foxp1
# Processing gene: Foxp2
# Processing gene: Frem2
# Processing gene: Frmd6
# Processing gene: Fzd2
# Processing gene: Fzd4
# Processing gene: Gabra2
# Processing gene: Gap43
# Processing gene: Gata6
# Processing gene: Gbx2
# Processing batch 5/12 with 50 genes
# Processing gene: Gdi1
# Processing gene: Gfra1
# Processing gene: Ggnbp2
# Processing gene: Gldc
# Processing gene: Gli3
# Processing gene: Glra1
# Processing gene: Gm10053
# Processing gene: Gm11223
# Processing gene: Gm11263
# Processing gene: Gm11518
# Processing gene: Gm37254
# Processing gene: Gm8292
# Processing gene: Gna13
# Processing gene: Gng3
# Processing gene: Gon4l
# Processing gene: Gpc3
# Processing gene: Gpm6a
# Processing gene: Gpm6b
# Processing gene: Gpr89
# Processing gene: Gprc5c
# Processing gene: Gpx3
# Processing gene: Gtpbp4
# Processing gene: Gyg
# Processing gene: Hacd2
# Processing gene: Hadha
# Processing gene: Hapln1
# Processing gene: Hba-a1
# Processing gene: Hba-a2
# Processing gene: Hba-x
# Processing gene: Hbb-bh1
# Processing gene: Hbb-bt
# Processing gene: Hbb-y
# Processing gene: Hbp1
# Processing gene: Hdac4
# Processing gene: Heatr5b
# Processing gene: Hipk1
# Processing gene: Hist1h1b
# Processing gene: Hmcn1
# Processing gene: Hmga1-rs1
# Processing gene: Hoxa2
# Processing gene: Hoxa3
# Processing gene: Hoxa5
# Processing gene: Hoxb4
# Processing gene: Hoxb5
# Processing gene: Hoxb6
# Processing gene: Hoxb7
# Processing gene: Hoxc4
# Processing gene: Hoxc5
# Processing gene: Hoxd4
# Processing gene: Hsbp1
# Processing batch 6/12 with 50 genes
# Processing gene: Hspa4l
# Processing gene: Id2
# Processing gene: Id3
# Processing gene: Id4
# Processing gene: Igf2r
# Processing gene: Igfbp5
# Processing gene: Igsf3
# Processing gene: Igsf8
# Processing gene: Ikzf2
# Processing gene: Il11ra1
# Processing gene: Ildr2
# Processing gene: Ina
# Processing gene: Irs4
# Processing gene: Irx2
# Processing gene: Islr2
# Processing gene: Itga4
# Processing gene: Itga6
# Processing gene: Itih5
# Processing gene: Itm2a
# Processing gene: Jam2
# Processing gene: Josd2
# Processing gene: Kank4
# Processing gene: Kcnd3
# Processing gene: Kctd12
# Processing gene: Kdm2a
# Processing gene: Kdm6b
# Processing gene: Kdm7a
# Processing gene: Kif15
# Processing gene: Kif1a
# Processing gene: Kif21a
# Processing gene: Klhdc10
# Processing gene: Krt8
# Processing gene: Lama4
# Processing gene: Lamc3
# Processing gene: Lamtor1
# Processing gene: Larp7
# Processing gene: Lef1
# Processing gene: Lgals1
# Processing gene: Lgr4
# Processing gene: Lhfpl4
# Processing gene: Lhx1
# Processing gene: Lhx2
# Processing gene: Limch1
# Processing gene: Limd2
# Processing gene: Lix1
# Processing gene: Lmo1
# Processing gene: Lpp
# Processing gene: Lrig3
# Processing gene: Lum
# Processing gene: Lzts2
# Processing batch 7/12 with 50 genes
# Processing gene: Maged2
# Processing gene: Map2
# Processing gene: Map6
# Processing gene: Mapk1
# Processing gene: Mapk10
# Processing gene: Mapk6
# Processing gene: Mapt
# Processing gene: March7
# Processing gene: Meis1
# Processing gene: Meis3
# Processing gene: Mfap2
# Processing gene: Mfap3
# Processing gene: Mfap4
# Processing gene: Mga
# Processing gene: Mical2
# Processing gene: Mif
# Processing gene: Mmp2
# Processing gene: Mpped1
# Processing gene: Mpped2
# Processing gene: Mrpl24
# Processing gene: Mrpl30
# Processing gene: Mrpl57
# Processing gene: Mrps16
# Processing gene: Mrps5
# Processing gene: Msl1
# Processing gene: Msx3
# Processing gene: Mybpc3
# Processing gene: Myh6
# Processing gene: Myh7
# Processing gene: Myl2
# Processing gene: Myl3
# Processing gene: Myl4
# Processing gene: Myl7
# Processing gene: Myl9
# Processing gene: Nanos3
# Processing gene: Napb
# Processing gene: Nav3
# Processing gene: Nbea
# Processing gene: Ncam1
# Processing gene: Ncaph
# Processing gene: Ndufa1
# Processing gene: Nectin3
# Processing gene: Nefl
# Processing gene: Nefm
# Processing gene: Nexn
# Processing gene: Nfatc4
# Processing gene: Nhlh2
# Processing gene: Nhp2l1
# Processing gene: Npas3
# Processing gene: Nr2e1
# Processing batch 8/12 with 50 genes
# Processing gene: Nr2f2
# Processing gene: Nrk
# Processing gene: Nrp1
# Processing gene: Nsg2
# Processing gene: Ntrk3
# Processing gene: Nudt4
# Processing gene: Numa1
# Processing gene: Nup133
# Processing gene: Ociad1
# Processing gene: Olig2
# Processing gene: Olig3
# Processing gene: Onecut2
# Processing gene: Onecut3
# Processing gene: Otp
# Processing gene: Otx1
# Processing gene: Otx2
# Processing gene: P3h3
# Processing gene: P4ha3
# Processing gene: Pak1
# Processing gene: Pak3
# Processing gene: Parm1
# Processing gene: Pax1
# Processing gene: Pax3
# Processing gene: Pax5
# Processing gene: Pax9
# Processing gene: Pbx3
# Processing gene: Pcdh19
# Processing gene: Pcm1
# Processing gene: Pcolce
# Processing gene: Pdgfa
# Processing gene: Pdhb
# Processing gene: Pdlim3
# Processing gene: Pdlim7
# Processing gene: Pdpn
# Processing gene: Pds5a
# Processing gene: Phf21b
# Processing gene: Phgdh
# Processing gene: Phox2b
# Processing gene: Phpt1
# Processing gene: Pitpnc1
# Processing gene: Pitx1
# Processing gene: Pitx2
# Processing gene: Pkdcc
# Processing gene: Plcd1
# Processing gene: Plch1
# Processing gene: Plekha8
# Processing gene: Plod2
# Processing gene: Plpp3
# Processing gene: Poglut1
# Processing gene: Polr1b
# Processing batch 9/12 with 50 genes
# Processing gene: Polr2j
# Processing gene: Pou3f2
# Processing gene: Pou4f1
# Processing gene: Pou6f2
# Processing gene: Pqbp1
# Processing gene: Prc1
# Processing gene: Prkacb
# Processing gene: Prkag1
# Processing gene: Prkd3
# Processing gene: Prmt5
# Processing gene: Prmt8
# Processing gene: Prox1
# Processing gene: Prrx1
# Processing gene: Ptch1
# Processing gene: Ptprd
# Processing gene: Ptprz1
# Processing gene: Pygo1
# Processing gene: Rarb
# Processing gene: Rbm5
# Processing gene: Rbmxl1
# Processing gene: Rbp1
# Processing gene: Rchy1
# Processing gene: Rcn3
# Processing gene: Rest
# Processing gene: Rexo1
# Processing gene: Rfc2
# Processing gene: Rnd2
# Processing gene: Rnd3
# Processing gene: Rnf165
# Processing gene: Rnps1
# Processing gene: Rock2
# Processing gene: Rpa2
# Processing gene: Rpl13-ps6
# Processing gene: Rpl17-ps8
# Processing gene: Rpl27-ps3
# Processing gene: Rpl7l1
# Processing gene: Rpl9-ps6
# Processing gene: Rps13-ps1
# Processing gene: Rps3a3
# Processing gene: Rraga
# Processing gene: Rspo1
# Processing gene: Rtn1
# Processing gene: Rufy3
# Processing gene: Sall1
# Processing gene: Sall2
# Processing gene: Sall3
# Processing gene: Sap30
# Processing gene: Scg3
# Processing gene: Sdf2l1
# Processing gene: Sec24b
# Processing batch 10/12 with 50 genes
# Processing gene: Sec61a1
# Processing gene: Sema5b
# Processing gene: Sf3b5
# Processing gene: Sfrp1
# Processing gene: Sgpp2
# Processing gene: Sh3bgr
# Processing gene: Sh3glb2
# Processing gene: Six1
# Processing gene: Six2
# Processing gene: Six3
# Processing gene: Six4
# Processing gene: Slc1a2
# Processing gene: Slc1a3
# Processing gene: Slc25a39
# Processing gene: Slc37a3
# Processing gene: Slirp
# Processing gene: Smap1
# Processing gene: Smc2
# Processing gene: Smchd1
# Processing gene: Smyd1
# Processing gene: Snhg11
# Processing gene: Snx27
# Processing gene: Sorbs2
# Processing gene: Sox12
# Processing gene: Sox5
# Processing gene: Sox9
# Processing gene: Sparc
# Processing gene: Sparcl1
# Processing gene: Spen
# Processing gene: Spsb4
# Processing gene: Sqle
# Processing gene: Srpk2
# Processing gene: Srrm4
# Processing gene: Srrt
# Processing gene: Ssr2
# Processing gene: Sst
# Processing gene: Stmn2
# Processing gene: Stx16
# Processing gene: Sulf1
# Processing gene: Sumo3
# Processing gene: Synpo
# Processing gene: Tab2
# Processing gene: Tac1
# Processing gene: Tagln
# Processing gene: Tagln3
# Processing gene: Tal2
# Processing gene: Tbx1
# Processing gene: Tbx20
# Processing gene: Tcf7l2
# Processing gene: Tenm3
# Processing batch 11/12 with 50 genes
# Processing gene: Tes
# Processing gene: Tfap2b
# Processing gene: Tgfb2
# Processing gene: Tgfbi
# Processing gene: Thsd7a
# Processing gene: Thumpd1
# Processing gene: Tle4
# Processing gene: Tmem132c
# Processing gene: Tmem214
# Processing gene: Tmod1
# Processing gene: Tmod2
# Processing gene: Tnc
# Processing gene: Tnfrsf19
# Processing gene: Tnnc1
# Processing gene: Tnni1
# Processing gene: Tnni3
# Processing gene: Tnnt2
# Processing gene: Tomm6
# Processing gene: Tpm1
# Processing gene: Tppp3
# Processing gene: Tra2a
# Processing gene: Tril
# Processing gene: Trim2
# Processing gene: Trio
# Processing gene: Trpm7
# Processing gene: Tsg101
# Processing gene: Tshz1
# Processing gene: Tshz3
# Processing gene: Tspan18
# Processing gene: Tspyl4
# Processing gene: Ttn
# Processing gene: Tubb6
# Processing gene: Tulp4
# Processing gene: Ube2v2
# Processing gene: Ube4b
# Processing gene: Ubfd1
# Processing gene: Ubn2
# Processing gene: Ubr2
# Processing gene: Ubxn1
# Processing gene: Unc5c
# Processing gene: Vamp8
# Processing gene: Vangl2
# Processing gene: Vcan
# Processing gene: Veph1
# Processing gene: Vgll4
# Processing gene: Vtn
# Processing gene: Wbp1
# Processing gene: Wls
# Processing gene: Wnt4
# Processing gene: Wnt8b
# Processing batch 12/12 with 18 genes
# Processing gene: Wwp2
# Processing gene: Xpo7
# Processing gene: Xpr1
# Processing gene: Ylpm1
# Processing gene: Zbtb26
# Processing gene: Zc3h13
# Processing gene: Zcchc12
# Processing gene: Zdbf2
# Processing gene: Zeb2
# Processing gene: Zfhx3
# Processing gene: Zfp157
# Processing gene: Zfp280d
# Processing gene: Zfp322a
# Processing gene: Zfp503
# Processing gene: Zfp655
# Processing gene: Zic1
# Processing gene: Zic3
# Processing gene: Zyx
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-4a9616bcddb1> in <cell line: 19>()
#      17
#      18 # Rank the genes based on distance
# ---> 19 df_results['Rank'] = df_results['Distance'].rank(ascending=False)
#      20
#      21 # Display top genes
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in rank(self, axis, method, numeric_only, na_option, ascending, pct)
#    8608         if numeric_only is None:
#    8609             try:
# -> 8610                 return ranker(self)
#    8611             except TypeError:
#    8612                 numeric_only = True
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in ranker(data)
#    8592                 )
#    8593             else:
# -> 8594                 ranks = algos.rank(
#    8595                     values,
#    8596                     axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in rank(values, axis, method, na_option, ascending, pct)
#    1006     values = _get_values_for_rank(values)
#    1007     if values.ndim == 1:
# -> 1008         ranks = algos.rank_1d(
#    1009             values,
#    1010             is_datetimelike=is_datetimelike,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/algos.pyx in pandas._libs.algos.rank_1d()
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in lexsort(*args, **kwargs)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ## Small batch

# %%
# Retrieve all gene names
all_genes = list(adata.var.index)

# Print all gene names
print("All genes in adata:")
for gene in all_genes:
    print(gene)
# Out:
# All genes in adata:
# 1810037I17Rik
# 2410002F23Rik
# 5730559C18Rik
# Aagab
# Aars2
# Acat1
# Acta2
# Actc1
# Actn1
# Acvr2b
# Adam10
# Adamts1
# Adamts18
# Adamtsl1
# Adgrl2
# Adgrv1
# Afap1
# Aff3
# Afg3l1
# Ahnak
# Akap7
# Aldh1a3
# Alx1
# Alx3
# Amotl1
# Anapc13
# Angptl2
# Ank2
# Ank3
# Ankrd1
# Anp32a
# Anxa2
# Ap1s2
# Ap2s1
# Apod
# Apoe
# Arf5
# Arhgap1
# Arhgap11a
# Arhgap35
# Arx
# Atp1b1
# Bach2
# Barhl2
# Bcl11a
# Bcl11b
# Bex1
# Bicc1
# Bri3
# Btg1
# Bub3
# C130093G08Rik
# C530008M17Rik
# Cadm1
# Cadps
# Camsap1
# Cand2
# Capn6
# Casz1
# Cbl
# Cblb
# Ccdc34
# Ccnt2
# Cd2bp2
# Cd47
# Cd63
# Cd81
# Cdk5r1
# Cds2
# Celsr2
# Cenpb
# Chd3
# Chl1
# Chmp4b
# Cks1b
# Clcn5
# Cldn6
# Cnn1
# Cnn2
# Cnpy1
# Cnr1
# Cntn2
# Cntnap2
# Col11a1
# Col12a1
# Col1a1
# Col1a2
# Col25a1
# Col26a1
# Col2a1
# Col3a1
# Col4a1
# Col4a2
# Col9a1
# Copb2
# Coq4
# Cox17
# Cox5a
# Cpe
# Cplx2
# Cpxm1
# Crabp1
# Crabp2
# Crcp
# Creb3l2
# Crebbp
# Crlf1
# Cryab
# Crym
# Csnk1e
# Ctnnbl1
# Ctsd
# Cxcl12
# Cxxc4
# D930015E06Rik
# Dab2
# Dbx1
# Dclk1
# Dcx
# Ddx1
# Des
# Dhx36
# Dicer1
# Dlk1
# Dlx1
# Dlx2
# Dmrta2
# Dnajc1
# Dnajc19
# Dnajc3
# Dpy19l1
# Dpysl4
# Dpysl5
# Draxin
# Dsp
# Dstn
# Dtl
# Dtx4
# Dtymk
# Dusp6
# Ebf1
# Ebf2
# Echs1
# Edf1
# Ednrb
# Efnb1
# Ehmt2
# Eif2b5
# Eif3d
# Eif4e2
# Eif4g3
# Elavl2
# Elavl3
# Elavl4
# Elk3
# Eml4
# Emx2
# En2
# Enpp2
# Epb41
# Epb41l3
# Epcam
# Epha5
# Epha7
# Epn1
# Ercc5
# Exosc10
# Eya1
# Ezr
# Fabp7
# Fam168b
# Fam192a
# Fbl
# Fbln1
# Fbln2
# Fbn2
# Fbxl2
# Fem1b
# Fezf1
# Fezf2
# Fgf13
# Fgfr1
# Fkbp2
# Fkbp9
# Flrt3
# Fmnl3
# Fndc5
# Foxc1
# Foxg1
# Foxo3
# Foxp1
# Foxp2
# Frem2
# Frmd6
# Fzd2
# Fzd4
# Gabra2
# Gap43
# Gata6
# Gbx2
# Gdi1
# Gfra1
# Ggnbp2
# Gldc
# Gli3
# Glra1
# Gm10053
# Gm11223
# Gm11263
# Gm11518
# Gm37254
# Gm8292
# Gna13
# Gng3
# Gon4l
# Gpc3
# Gpm6a
# Gpm6b
# Gpr89
# Gprc5c
# Gpx3
# Gtpbp4
# Gyg
# Hacd2
# Hadha
# Hapln1
# Hba-a1
# Hba-a2
# Hba-x
# Hbb-bh1
# Hbb-bt
# Hbb-y
# Hbp1
# Hdac4
# Heatr5b
# Hipk1
# Hist1h1b
# Hmcn1
# Hmga1-rs1
# Hoxa2
# Hoxa3
# Hoxa5
# Hoxb4
# Hoxb5
# Hoxb6
# Hoxb7
# Hoxc4
# Hoxc5
# Hoxd4
# Hsbp1
# Hspa4l
# Id2
# Id3
# Id4
# Igf2r
# Igfbp5
# Igsf3
# Igsf8
# Ikzf2
# Il11ra1
# Ildr2
# Ina
# Irs4
# Irx2
# Islr2
# Itga4
# Itga6
# Itih5
# Itm2a
# Jam2
# Josd2
# Kank4
# Kcnd3
# Kctd12
# Kdm2a
# Kdm6b
# Kdm7a
# Kif15
# Kif1a
# Kif21a
# Klhdc10
# Krt8
# Lama4
# Lamc3
# Lamtor1
# Larp7
# Lef1
# Lgals1
# Lgr4
# Lhfpl4
# Lhx1
# Lhx2
# Limch1
# Limd2
# Lix1
# Lmo1
# Lpp
# Lrig3
# Lum
# Lzts2
# Maged2
# Map2
# Map6
# Mapk1
# Mapk10
# Mapk6
# Mapt
# March7
# Meis1
# Meis3
# Mfap2
# Mfap3
# Mfap4
# Mga
# Mical2
# Mif
# Mmp2
# Mpped1
# Mpped2
# Mrpl24
# Mrpl30
# Mrpl57
# Mrps16
# Mrps5
# Msl1
# Msx3
# Mybpc3
# Myh6
# Myh7
# Myl2
# Myl3
# Myl4
# Myl7
# Myl9
# Nanos3
# Napb
# Nav3
# Nbea
# Ncam1
# Ncaph
# Ndufa1
# Nectin3
# Nefl
# Nefm
# Nexn
# Nfatc4
# Nhlh2
# Nhp2l1
# Npas3
# Nr2e1
# Nr2f2
# Nrk
# Nrp1
# Nsg2
# Ntrk3
# Nudt4
# Numa1
# Nup133
# Ociad1
# Olig2
# Olig3
# Onecut2
# Onecut3
# Otp
# Otx1
# Otx2
# P3h3
# P4ha3
# Pak1
# Pak3
# Parm1
# Pax1
# Pax3
# Pax5
# Pax9
# Pbx3
# Pcdh19
# Pcm1
# Pcolce
# Pdgfa
# Pdhb
# Pdlim3
# Pdlim7
# Pdpn
# Pds5a
# Phf21b
# Phgdh
# Phox2b
# Phpt1
# Pitpnc1
# Pitx1
# Pitx2
# Pkdcc
# Plcd1
# Plch1
# Plekha8
# Plod2
# Plpp3
# Poglut1
# Polr1b
# Polr2j
# Pou3f2
# Pou4f1
# Pou6f2
# Pqbp1
# Prc1
# Prkacb
# Prkag1
# Prkd3
# Prmt5
# Prmt8
# Prox1
# Prrx1
# Ptch1
# Ptprd
# Ptprz1
# Pygo1
# Rarb
# Rbm5
# Rbmxl1
# Rbp1
# Rchy1
# Rcn3
# Rest
# Rexo1
# Rfc2
# Rnd2
# Rnd3
# Rnf165
# Rnps1
# Rock2
# Rpa2
# Rpl13-ps6
# Rpl17-ps8
# Rpl27-ps3
# Rpl7l1
# Rpl9-ps6
# Rps13-ps1
# Rps3a3
# Rraga
# Rspo1
# Rtn1
# Rufy3
# Sall1
# Sall2
# Sall3
# Sap30
# Scg3
# Sdf2l1
# Sec24b
# Sec61a1
# Sema5b
# Sf3b5
# Sfrp1
# Sgpp2
# Sh3bgr
# Sh3glb2
# Six1
# Six2
# Six3
# Six4
# Slc1a2
# Slc1a3
# Slc25a39
# Slc37a3
# Slirp
# Smap1
# Smc2
# Smchd1
# Smyd1
# Snhg11
# Snx27
# Sorbs2
# Sox12
# Sox5
# Sox9
# Sparc
# Sparcl1
# Spen
# Spsb4
# Sqle
# Srpk2
# Srrm4
# Srrt
# Ssr2
# Sst
# Stmn2
# Stx16
# Sulf1
# Sumo3
# Synpo
# Tab2
# Tac1
# Tagln
# Tagln3
# Tal2
# Tbx1
# Tbx20
# Tcf7l2
# Tenm3
# Tes
# Tfap2b
# Tgfb2
# Tgfbi
# Thsd7a
# Thumpd1
# Tle4
# Tmem132c
# Tmem214
# Tmod1
# Tmod2
# Tnc
# Tnfrsf19
# Tnnc1
# Tnni1
# Tnni3
# Tnnt2
# Tomm6
# Tpm1
# Tppp3
# Tra2a
# Tril
# Trim2
# Trio
# Trpm7
# Tsg101
# Tshz1
# Tshz3
# Tspan18
# Tspyl4
# Ttn
# Tubb6
# Tulp4
# Ube2v2
# Ube4b
# Ubfd1
# Ubn2
# Ubr2
# Ubxn1
# Unc5c
# Vamp8
# Vangl2
# Vcan
# Veph1
# Vgll4
# Vtn
# Wbp1
# Wls
# Wnt4
# Wnt8b
# Wwp2
# Xpo7
# Xpr1
# Ylpm1
# Zbtb26
# Zc3h13
# Zcchc12
# Zdbf2
# Zeb2
# Zfhx3
# Zfp157
# Zfp280d
# Zfp322a
# Zfp503
# Zfp655
# Zic1
# Zic3
# Zyx

# %%
# Get the first three genes in adata.var.index
genes_of_interest = adata.var.index[:3].tolist()
print(f"Genes to knock out: {genes_of_interest}")
# Out:
# Genes to knock out: ['1810037I17Rik', '2410002F23Rik', '5730559C18Rik']

# %%
# adata pre-processing to prepare for input in the GenKI tool
adata.layers["norm"] = adata.X.copy()

# Ensure adata.X is in sparse matrix format
if not issparse(adata.X):
    adata.X = csr_matrix(adata.X)
    print("Converted adata.X to a sparse matrix.")
else:
    print("adata.X is already a sparse matrix.")
# Out:
# adata.X is already a sparse matrix.

# %%
# Load data with multiple target genes
data_wrapper = DataLoader(
    adata,  # adata object
    target_gene=genes_of_interest,  # KO gene names
    target_cell=None,  # Use all cells
    obs_label="ident",  # Column name for genes (adjust if needed)
    GRN_file_dir="GRNs",  # Folder name for GRNs
    rebuild_GRN=True,  # Build GRN by pcNet
    pcNet_name="DBiTseq_example_multiKO",  # GRN file name
    verbose=True,  # Verbose output
    n_cpus=8,  # Number of CPUs for multiprocessing
)
# Out:
# use all the cells (936) in adata
# build GRN
# 2024-10-31 06:48:15,052	INFO worker.py:1816 -- Started a local Ray instance.
# ray init, using 8 CPUs
# execution time of making pcNet: 202.45 s
# GRN has been built and saved in "GRNs/DBiTseq_example_multiKO.npz"
# init completed

# %%
data_wt = data_wrapper.load_data()
data_ko = data_wrapper.load_kodata()

# %%
# Set hyperparameters
hyperparams = {
    "epochs": 300,  # Increased epochs for more training
    "lr": 5e-2,     # Adjusted learning rate
    "beta": 5e-4,   # Increased beta for stronger regularization
    "seed": 8096    # Seed for reproducibility
}

log_dir = None  # Set log directory if needed

# Initialize and train the VGAE model
sensei = VGAE_trainer(
    data_wt,
    epochs=hyperparams["epochs"],
    lr=hyperparams["lr"],
    log_dir=log_dir,
    beta=hyperparams["beta"],
    seed=hyperparams["seed"],
    verbose=False,
)
sensei.train()

# %%
# Get latent variables for WT and KO data
z_mu_wt, z_std_wt = sensei.get_latent_vars(data_wt)
z_mu_ko, z_std_ko = sensei.get_latent_vars(data_ko)

# Calculate the distance using KL divergence
dis = gk.utils.get_distance(z_mu_ko, z_std_ko, z_mu_wt, z_std_wt, by="KL")
print(f"Distance shape: {dis.shape}")
# Out:
# Distance shape: (568,)

# %%
# Get the ranked list of genes based on the calculated distances
res_raw = utils.get_generank(data_wt, dis, rank=True)

# Display the top 10 responsive genes
top_genes = res_raw.head(10)
print("Top 10 KO Responsive Genes:")
print(top_genes)
# Out:
# Top 10 KO Responsive Genes:
#                      dis  rank
# 1810037I17Rik  72.716254     1
# 5730559C18Rik   0.054792     2
# Col3a1          0.045720     3
# Col1a2          0.027975     4
# Bcl11a          0.026990     5
# Fbn2            0.021538     6
# Sox9            0.020365     7
# Meis1           0.020127     8
# Gm11263         0.019654     9
# Foxp2           0.018440    10

# %%
top_responsive_genes = {}

for gene_of_interest in genes_of_interest:
    print(f"\nProcessing gene: {gene_of_interest}")
    # Rest of the code inside the loop, adjusting 'target_gene=[gene_of_interest]' and 'pcNet_name' accordingly
    # ...
    top_genes = res_raw.head(10)
    top_responsive_genes[gene_of_interest] = top_genes

# Now you can access the top responsive genes for each gene individually
for gene, genes_df in top_responsive_genes.items():
    print(f"\nTop 10 KO Responsive Genes for {gene}:")
    print(genes_df)
# Out:
# Processing gene: 1810037I17Rik
#
# Processing gene: 2410002F23Rik
#
# Processing gene: 5730559C18Rik
#
# Top 10 KO Responsive Genes for 1810037I17Rik:
#                      dis  rank
# 1810037I17Rik  72.716254     1
# 5730559C18Rik   0.054792     2
# Col3a1          0.045720     3
# Col1a2          0.027975     4
# Bcl11a          0.026990     5
# Fbn2            0.021538     6
# Sox9            0.020365     7
# Meis1           0.020127     8
# Gm11263         0.019654     9
# Foxp2           0.018440    10
#
# Top 10 KO Responsive Genes for 2410002F23Rik:
#                      dis  rank
# 1810037I17Rik  72.716254     1
# 5730559C18Rik   0.054792     2
# Col3a1          0.045720     3
# Col1a2          0.027975     4
# Bcl11a          0.026990     5
# Fbn2            0.021538     6
# Sox9            0.020365     7
# Meis1           0.020127     8
# Gm11263         0.019654     9
# Foxp2           0.018440    10
#
# Top 10 KO Responsive Genes for 5730559C18Rik:
#                      dis  rank
# 1810037I17Rik  72.716254     1
# 5730559C18Rik   0.054792     2
# Col3a1          0.045720     3
# Col1a2          0.027975     4
# Bcl11a          0.026990     5
# Fbn2            0.021538     6
# Sox9            0.020365     7
# Meis1           0.020127     8
# Gm11263         0.019654     9
# Foxp2           0.018440    10

# %% [markdown]
# ### another try

# %%
# Step 1: Get the first three genes
genes_of_interest = adata.var.index[:3].tolist()
print(f"Genes to knock out: {genes_of_interest}")

# Step 2: Verify genes are present
for gene in genes_of_interest.copy():
    if gene not in adata.var.index:
        print(f"The gene {gene} is not present in the dataset and will be removed from the target list.")
        genes_of_interest.remove(gene)
print(f"Final list of genes to knock out: {genes_of_interest}")

# Step 3: Prepare adata
adata.layers["norm"] = adata.X.copy()
if not issparse(adata.X):
    adata.X = csr_matrix(adata.X)
    print("Converted adata.X to a sparse matrix.")
else:
    print("adata.X is already a sparse matrix.")

# Step 4: Initialize DataLoader and load WT data
# Use a dummy gene
dummy_gene = adata.var.index[0]

# Initialize DataLoader with rebuild_GRN=True to build the GRN during data loading
data_wrapper_wt = DataLoader(
    adata,
    target_gene=[dummy_gene],  # Use a dummy gene
    target_cell=None,
    obs_label="cell_type",  # Adjust if needed
    GRN_file_dir="GRNs",
    rebuild_GRN=True,  # Build the GRN during data loading
    pcNet_name="DBiTseq_example",
    verbose=True,
    n_cpus=8,
)

# Load WT data and build the GRN
data_wt = data_wrapper_wt.load_data()
# At this point, the GRN has been built and saved

# Step 5: Set hyperparameters and train the model once
hyperparams = {
    "epochs": 300,
    "lr": 5e-2,
    "beta": 5e-4,
    "seed": 8096
}
sensei = VGAE_trainer(
    data_wt,
    epochs=hyperparams["epochs"],
    lr=hyperparams["lr"],
    log_dir=None,
    beta=hyperparams["beta"],
    seed=hyperparams["seed"],
    verbose=False,
)
sensei.train()

# Step 6: Get latent variables for WT data
z_mu_wt, z_std_wt = sensei.get_latent_vars(data_wt)

# Step 7: Loop over each gene to KO and get responsive genes
top_responsive_genes = {}

for gene_of_interest in genes_of_interest:
    print(f"\nProcessing gene: {gene_of_interest}")

    # Prepare data_ko for this gene
    data_wrapper_ko = DataLoader(
        adata,
        target_gene=[gene_of_interest],
        target_cell=None,
        obs_label="cell_type",
        GRN_file_dir="GRNs",
        rebuild_GRN=False,  # Use the prebuilt GRN
        pcNet_name="DBiTseq_example",
        verbose=True,
        n_cpus=8,
    )
    data_ko = data_wrapper_ko.load_kodata()

    # Get latent variables for KO data
    z_mu_ko, z_std_ko = sensei.get_latent_vars(data_ko)

    # Calculate the distance between WT and KO data
    dis = gk.utils.get_distance(z_mu_ko, z_std_ko, z_mu_wt, z_std_wt, by="KL")
    print(f"Distance shape: {dis.shape}")

    # Get the ranked list of responsive genes
    res_raw = utils.get_generank(data_wt, dis, rank=True)

    # Display and store the top 10 responsive genes
    top_genes = res_raw.head(10)
    print(f"Top 10 KO Responsive Genes for {gene_of_interest}:")
    print(top_genes)
    top_responsive_genes[gene_of_interest] = top_genes

# Step 8: Access the top responsive genes for each gene
for gene, genes_df in top_responsive_genes.items():
    print(f"\nTop 10 KO Responsive Genes for {gene}:")
    print(genes_df)
# Out:
# Genes to knock out: ['1810037I17Rik', '2410002F23Rik', '5730559C18Rik']
# Final list of genes to knock out: ['1810037I17Rik', '2410002F23Rik', '5730559C18Rik']
# adata.X is already a sparse matrix.
# use all the cells (936) in adata
# build GRN
# 2024-10-31 07:42:26,555	INFO worker.py:1816 -- Started a local Ray instance.
# ray init, using 8 CPUs
# execution time of making pcNet: 190.84 s
# GRN has been built and saved in "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: 1810037I17Rik
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
# Distance shape: (568,)
# Top 10 KO Responsive Genes for 1810037I17Rik:
#                      dis  rank
# 1810037I17Rik  72.716254     1
# Col3a1          0.045720     2
# Col1a2          0.027975     3
# Bcl11a          0.026990     4
# Fbn2            0.021538     5
# Sox9            0.020365     6
# Meis1           0.020127     7
# Gm11263         0.019654     8
# Foxp2           0.018440     9
# Id2             0.017870    10
#
# Processing gene: 2410002F23Rik
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
# Distance shape: (568,)
# Top 10 KO Responsive Genes for 2410002F23Rik:
#                     dis  rank
# 2410002F23Rik  0.003002     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Processing gene: 5730559C18Rik
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
# Distance shape: (568,)
# Top 10 KO Responsive Genes for 5730559C18Rik:
#                     dis  rank
# 5730559C18Rik  0.054792     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for 1810037I17Rik:
#                      dis  rank
# 1810037I17Rik  72.716254     1
# Col3a1          0.045720     2
# Col1a2          0.027975     3
# Bcl11a          0.026990     4
# Fbn2            0.021538     5
# Sox9            0.020365     6
# Meis1           0.020127     7
# Gm11263         0.019654     8
# Foxp2           0.018440     9
# Id2             0.017870    10
#
# Top 10 KO Responsive Genes for 2410002F23Rik:
#                     dis  rank
# 2410002F23Rik  0.003002     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for 5730559C18Rik:
#                     dis  rank
# 5730559C18Rik  0.054792     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10

# %%
# Prepare adata
if not issparse(adata.X):
    adata.layers["norm"] = adata.X.copy()
    adata.X = csr_matrix(adata.X)
    print("Converted adata.X to a sparse matrix.")
else:
    print("adata.X is already a sparse matrix.")

# Get the first three genes
genes_of_interest = adata.var.index[:3].tolist()
print(f"Genes to knock out: {genes_of_interest}")

# Verify genes are present
for gene in genes_of_interest.copy():
    if gene not in adata.var.index:
        print(f"The gene {gene} is not present in the dataset and will be removed from the target list.")
        genes_of_interest.remove(gene)
print(f"Final list of genes to knock out: {genes_of_interest}")

# Select a dummy gene not in genes_of_interest
all_genes = list(adata.var.index)
dummy_gene = next(g for g in all_genes if g not in genes_of_interest)
print(f"Using dummy gene for WT data: {dummy_gene}")

# Initialize DataLoader for WT data using the dummy gene
data_wrapper_wt = DataLoader(
    adata,
    target_gene=[dummy_gene],
    target_cell=None,
    obs_label="cell_type",  # Adjust if necessary
    GRN_file_dir="GRNs",
    rebuild_GRN=True,  # Build GRN
    pcNet_name="DBiTseq_example",
    verbose=True,
    n_cpus=8,
)

# Load WT data (GRN will be built here)
data_wt = data_wrapper_wt.load_data()

# Set hyperparameters
hyperparams = {
    "epochs": 300,
    "lr": 5e-2,
    "beta": 5e-4,
    "seed": 8096
}

# Train the model on WT data
sensei = VGAE_trainer(
    data_wt,
    epochs=hyperparams["epochs"],
    lr=hyperparams["lr"],
    beta=hyperparams["beta"],
    seed=hyperparams["seed"],
    verbose=False,
)

sensei.train()

# Get latent variables for WT data
z_mu_wt, z_std_wt = sensei.get_latent_vars(data_wt)

# Initialize a dictionary to store results
top_responsive_genes = {}

for gene_of_interest in genes_of_interest:
    print(f"\nProcessing gene: {gene_of_interest}")

    # Initialize DataLoader for KO data
    data_wrapper_ko = DataLoader(
        adata,
        target_gene=[gene_of_interest],
        target_cell=None,
        obs_label="cell_type",
        GRN_file_dir="GRNs",
        rebuild_GRN=False,  # Use the existing GRN
        pcNet_name="DBiTseq_example",
        verbose=True,
        n_cpus=8,
    )

    # Load KO data for the gene
    data_ko = data_wrapper_ko.load_kodata()

    # Get latent variables for KO data
    z_mu_ko, z_std_ko = sensei.get_latent_vars(data_ko)

    # Calculate the distance between WT and KO data
    dis = gk.utils.get_distance(z_mu_ko, z_std_ko, z_mu_wt, z_std_wt, by="KL")

    # Get the ranked list of responsive genes
    res_raw = utils.get_generank(data_wt, dis, rank=True)

    # Store the top 10 responsive genes
    top_genes = res_raw.head(10)
    top_responsive_genes[gene_of_interest] = top_genes

# Display the results
for gene, df in top_responsive_genes.items():
    print(f"\nTop 10 KO Responsive Genes for {gene}:")
    print(df)
# Out:
# adata.X is already a sparse matrix.
# Genes to knock out: ['1810037I17Rik', '2410002F23Rik', '5730559C18Rik']
# Final list of genes to knock out: ['1810037I17Rik', '2410002F23Rik', '5730559C18Rik']
# Using dummy gene for WT data: Aagab
# use all the cells (936) in adata
# build GRN
# 2024-10-31 07:50:50,630	INFO worker.py:1816 -- Started a local Ray instance.
# ray init, using 8 CPUs
# execution time of making pcNet: 189.27 s
# GRN has been built and saved in "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: 1810037I17Rik
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: 2410002F23Rik
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: 5730559C18Rik
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Top 10 KO Responsive Genes for 1810037I17Rik:
#                      dis  rank
# 1810037I17Rik  72.716254     1
# Col3a1          0.045720     2
# Col1a2          0.027975     3
# Bcl11a          0.026990     4
# Fbn2            0.021538     5
# Sox9            0.020365     6
# Meis1           0.020127     7
# Gm11263         0.019654     8
# Foxp2           0.018440     9
# Id2             0.017870    10
#
# Top 10 KO Responsive Genes for 2410002F23Rik:
#                     dis  rank
# 2410002F23Rik  0.003002     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for 5730559C18Rik:
#                     dis  rank
# 5730559C18Rik  0.054792     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10

# %%
# for ten genes

# Get the first 10 genes in adata.var.index
genes_of_interest = adata.var.index[:10].tolist()
print(f"Genes to knock out: {genes_of_interest}")

# Select a dummy gene not in genes_of_interest
all_genes = list(adata.var.index)
dummy_gene = next(g for g in all_genes if g not in genes_of_interest)
print(f"Using dummy gene for WT data: {dummy_gene}")


# Initialize DataLoader for WT data
data_wrapper_wt = DataLoader(
    adata,
    target_gene=[dummy_gene],  # Use the dummy gene
    target_cell=None,
    obs_label="cell_type",  # Adjust if necessary
    GRN_file_dir="GRNs",
    rebuild_GRN=True,  # Build the GRN
    pcNet_name="DBiTseq_example",
    verbose=True,
    n_cpus=8,
)

# Load WT data (GRN will be built here)
data_wt = data_wrapper_wt.load_data()

# Set hyperparameters
hyperparams = {
    "epochs": 300,
    "lr": 5e-2,
    "beta": 5e-4,
    "seed": 8096,
}

# Train the model on WT data
sensei = VGAE_trainer(
    data_wt,
    epochs=hyperparams["epochs"],
    lr=hyperparams["lr"],
    beta=hyperparams["beta"],
    seed=hyperparams["seed"],
    verbose=False,
)

sensei.train()

# Get latent variables for WT data
z_mu_wt, z_std_wt = sensei.get_latent_vars(data_wt)

# Initialize a dictionary to store results
top_responsive_genes = {}

for gene_of_interest in genes_of_interest:
    print(f"\nProcessing gene: {gene_of_interest}")

    # Initialize DataLoader for KO data
    data_wrapper_ko = DataLoader(
        adata,
        target_gene=[gene_of_interest],
        target_cell=None,
        obs_label="cell_type",
        GRN_file_dir="GRNs",
        rebuild_GRN=False,  # Use the existing GRN
        pcNet_name="DBiTseq_example",
        verbose=True,
        n_cpus=8,
    )

    # Load KO data for the gene
    data_ko = data_wrapper_ko.load_kodata()

    # Get latent variables for KO data
    z_mu_ko, z_std_ko = sensei.get_latent_vars(data_ko)

    # Calculate the distance between WT and KO data
    dis = gk.utils.get_distance(z_mu_ko, z_std_ko, z_mu_wt, z_std_wt, by="KL")

    # Get the ranked list of responsive genes
    res_raw = utils.get_generank(data_wt, dis, rank=True)

    # Store the top 10 responsive genes
    top_genes = res_raw.head(10)
    top_responsive_genes[gene_of_interest] = top_genes

    # Display the results
for gene, df in top_responsive_genes.items():
    print(f"\nTop 10 KO Responsive Genes for {gene}:")
    print(df)
# Out:
# Genes to knock out: ['1810037I17Rik', '2410002F23Rik', '5730559C18Rik', 'Aagab', 'Aars2', 'Acat1', 'Acta2', 'Actc1', 'Actn1', 'Acvr2b']
# Using dummy gene for WT data: Adam10
# use all the cells (936) in adata
# build GRN
# 2024-10-31 08:28:24,699	INFO worker.py:1816 -- Started a local Ray instance.
# ray init, using 8 CPUs
# execution time of making pcNet: 185.93 s
# GRN has been built and saved in "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: 1810037I17Rik
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: 2410002F23Rik
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: 5730559C18Rik
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: Aagab
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: Aars2
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: Acat1
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: Acta2
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: Actc1
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: Actn1
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Processing gene: Acvr2b
# use all the cells (936) in adata
# loading GRN from "GRNs/DBiTseq_example.npz"
# init completed
#
#
# Top 10 KO Responsive Genes for 1810037I17Rik:
#                      dis  rank
# 1810037I17Rik  72.716254     1
# Col3a1          0.045720     2
# Col1a2          0.027975     3
# Bcl11a          0.026990     4
# Fbn2            0.021538     5
# Sox9            0.020365     6
# Meis1           0.020127     7
# Gm11263         0.019654     8
# Foxp2           0.018440     9
# Id2             0.017870    10
#
# Top 10 KO Responsive Genes for 2410002F23Rik:
#                     dis  rank
# 2410002F23Rik  0.003002     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for 5730559C18Rik:
#                     dis  rank
# 5730559C18Rik  0.054792     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for Aagab:
#              dis  rank
# Pak3    2.210185     1
# Aagab   0.335850     2
# Col3a1  0.003313     3
# Ptprz1  0.002357     4
# Fbn2    0.002146     5
# Lhx2    0.001898     6
# Cnn2    0.001790     7
# Gpc3    0.001615     8
# Glra1   0.001569     9
# Col1a2  0.001495    10
#
# Top 10 KO Responsive Genes for Aars2:
#                     dis  rank
# Aars2          0.003002     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for Acat1:
#                     dis  rank
# Acat1          5.785017     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for Acta2:
#                   dis  rank
# Acta2    11424.605817     1
# Hba-x        0.918715     2
# Hba-a2       0.885070     3
# Hbb-y        0.867944     4
# Hba-a1       0.846784     5
# Hbb-bh1      0.806567     6
# Igfbp5       0.609059     7
# Gpc3         0.557601     8
# Vcan         0.443747     9
# Rbp1         0.440497    10
#
# Top 10 KO Responsive Genes for Actc1:
#                 dis  rank
# Actc1   3737.284399     1
# Col3a1     9.363615     2
# Col1a2     3.128645     3
# Col4a1     2.269822     4
# Cxcl12     1.914578     5
# Foxp2      1.672987     6
# Hba-a2     1.563326     7
# Hbb-y      1.481038     8
# Hba-a1     1.473053     9
# Hba-x      1.443725    10
#
# Top 10 KO Responsive Genes for Actn1:
#                dis  rank
# Actn1   542.428654     1
# Col3a1    2.789334     2
# Fbn2      1.582850     3
# Lgals1    1.500169     4
# Cnn2      1.034177     5
# Hba-a2    0.986208     6
# Col4a1    0.953604     7
# Vcan      0.925915     8
# Col1a1    0.901832     9
# Hbb-y     0.893394    10
#
# Top 10 KO Responsive Genes for Acvr2b:
#                   dis  rank
# Acvr2b   71228.365432     1
# Col3a1      10.183204     2
# Fbn2         4.689621     3
# Hbb-y        4.116543     4
# Cnn2         3.948414     5
# Rbp1         3.847355     6
# Hbb-bh1      3.632207     7
# Hba-a2       3.186872     8
# Hba-x        3.030815     9
# Hba-a1       2.818607    10

# %% [markdown]
# ## First 50 genes

# %%
# 50 genes

# Get the first 50 genes in adata.var.index
genes_of_interest = adata.var.index[:50].tolist()
print(f"Genes to knock out: {genes_of_interest}")

# Select a dummy gene not in genes_of_interest
all_genes = list(adata.var.index)
dummy_gene = next(g for g in all_genes if g not in genes_of_interest)
print(f"Using dummy gene for WT data: {dummy_gene}")

# Initialize DataLoader for WT data
data_wrapper_wt = DataLoader(
    adata,
    target_gene=[dummy_gene],  # Use the dummy gene: Bub3
    target_cell=None,
    obs_label="cell_type",  # Adjust if necessary
    GRN_file_dir="GRNs",
    rebuild_GRN=True,  # Build the GRN
    pcNet_name="DBiTseq_example",
    verbose=False,  # Set to False to reduce output
    n_cpus=8,
)

# Load WT data (GRN will be built here)
data_wt = data_wrapper_wt.load_data()


# Set hyperparameters
hyperparams = {
    "epochs": 300,
    "lr": 5e-2,
    "beta": 5e-4,
    "seed": 8096,
}

# Train the model on WT data
sensei = VGAE_trainer(
    data_wt,
    epochs=hyperparams["epochs"],
    lr=hyperparams["lr"],
    beta=hyperparams["beta"],
    seed=hyperparams["seed"],
    verbose=False,  # Set to False to reduce output
)

sensei.train()

# Get latent variables for WT data
z_mu_wt, z_std_wt = sensei.get_latent_vars(data_wt)


# Initialize a dictionary to store results
top_responsive_genes = {}

for gene_of_interest in genes_of_interest:
    print(f"\nProcessing gene: {gene_of_interest}")

    # Initialize DataLoader for KO data
    data_wrapper_ko = DataLoader(
        adata,
        target_gene=[gene_of_interest],
        target_cell=None,
        obs_label="cell_type",
        GRN_file_dir="GRNs",
        rebuild_GRN=False,  # Use the existing GRN
        pcNet_name="DBiTseq_example",
        verbose=False,  # Set to False to reduce output
        n_cpus=8,
    )

    # Load KO data for the gene
    data_ko = data_wrapper_ko.load_kodata()

    # Get latent variables for KO data
    z_mu_ko, z_std_ko = sensei.get_latent_vars(data_ko)

    # Calculate the distance between WT and KO data
    dis = gk.utils.get_distance(z_mu_ko, z_std_ko, z_mu_wt, z_std_wt, by="KL")

    # Get the ranked list of responsive genes
    res_raw = utils.get_generank(data_wt, dis, rank=True)

    # Store the top 10 responsive genes
    top_genes = res_raw.head(10)
    top_responsive_genes[gene_of_interest] = top_genes

    # Display the results
for gene, df in top_responsive_genes.items():
    print(f"\nTop 10 KO Responsive Genes for {gene}:")
    print(df)
# Out:
# Genes to knock out: ['1810037I17Rik', '2410002F23Rik', '5730559C18Rik', 'Aagab', 'Aars2', 'Acat1', 'Acta2', 'Actc1', 'Actn1', 'Acvr2b', 'Adam10', 'Adamts1', 'Adamts18', 'Adamtsl1', 'Adgrl2', 'Adgrv1', 'Afap1', 'Aff3', 'Afg3l1', 'Ahnak', 'Akap7', 'Aldh1a3', 'Alx1', 'Alx3', 'Amotl1', 'Anapc13', 'Angptl2', 'Ank2', 'Ank3', 'Ankrd1', 'Anp32a', 'Anxa2', 'Ap1s2', 'Ap2s1', 'Apod', 'Apoe', 'Arf5', 'Arhgap1', 'Arhgap11a', 'Arhgap35', 'Arx', 'Atp1b1', 'Bach2', 'Barhl2', 'Bcl11a', 'Bcl11b', 'Bex1', 'Bicc1', 'Bri3', 'Btg1']
# Using dummy gene for WT data: Bub3
# 2024-10-31 08:37:20,801	INFO worker.py:1816 -- Started a local Ray instance.
# ray init, using 8 CPUs
#
# Processing gene: 1810037I17Rik
#
# Processing gene: 2410002F23Rik
#
# Processing gene: 5730559C18Rik
#
# Processing gene: Aagab
#
# Processing gene: Aars2
#
# Processing gene: Acat1
#
# Processing gene: Acta2
#
# Processing gene: Actc1
#
# Processing gene: Actn1
#
# Processing gene: Acvr2b
#
# Processing gene: Adam10
#
# Processing gene: Adamts1
#
# Processing gene: Adamts18
#
# Processing gene: Adamtsl1
#
# Processing gene: Adgrl2
#
# Processing gene: Adgrv1
#
# Processing gene: Afap1
#
# Processing gene: Aff3
#
# Processing gene: Afg3l1
#
# Processing gene: Ahnak
#
# Processing gene: Akap7
#
# Processing gene: Aldh1a3
#
# Processing gene: Alx1
#
# Processing gene: Alx3
#
# Processing gene: Amotl1
#
# Processing gene: Anapc13
#
# Processing gene: Angptl2
#
# Processing gene: Ank2
#
# Processing gene: Ank3
#
# Processing gene: Ankrd1
#
# Processing gene: Anp32a
#
# Processing gene: Anxa2
#
# Processing gene: Ap1s2
#
# Processing gene: Ap2s1
#
# Processing gene: Apod
#
# Processing gene: Apoe
#
# Processing gene: Arf5
#
# Processing gene: Arhgap1
#
# Processing gene: Arhgap11a
#
# Processing gene: Arhgap35
#
# Processing gene: Arx
#
# Processing gene: Atp1b1
#
# Processing gene: Bach2
#
# Processing gene: Barhl2
#
# Processing gene: Bcl11a
#
# Processing gene: Bcl11b
#
# Processing gene: Bex1
#
# Processing gene: Bicc1
#
# Processing gene: Bri3
#
# Processing gene: Btg1
#
# Top 10 KO Responsive Genes for 1810037I17Rik:
#                      dis  rank
# 1810037I17Rik  72.716254     1
# Col3a1          0.045720     2
# Col1a2          0.027975     3
# Bcl11a          0.026990     4
# Fbn2            0.021538     5
# Sox9            0.020365     6
# Meis1           0.020127     7
# Gm11263         0.019654     8
# Foxp2           0.018440     9
# Id2             0.017870    10
#
# Top 10 KO Responsive Genes for 2410002F23Rik:
#                     dis  rank
# 2410002F23Rik  0.003002     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for 5730559C18Rik:
#                     dis  rank
# 5730559C18Rik  0.054792     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for Aagab:
#              dis  rank
# Pak3    2.210185     1
# Aagab   0.335850     2
# Col3a1  0.003313     3
# Ptprz1  0.002357     4
# Fbn2    0.002146     5
# Lhx2    0.001898     6
# Cnn2    0.001790     7
# Gpc3    0.001615     8
# Glra1   0.001569     9
# Col1a2  0.001495    10
#
# Top 10 KO Responsive Genes for Aars2:
#                     dis  rank
# Aars2          0.003002     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for Acat1:
#                     dis  rank
# Acat1          5.785017     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for Acta2:
#                   dis  rank
# Acta2    11424.605817     1
# Hba-x        0.918715     2
# Hba-a2       0.885070     3
# Hbb-y        0.867944     4
# Hba-a1       0.846784     5
# Hbb-bh1      0.806567     6
# Igfbp5       0.609059     7
# Gpc3         0.557601     8
# Vcan         0.443747     9
# Rbp1         0.440497    10
#
# Top 10 KO Responsive Genes for Actc1:
#                 dis  rank
# Actc1   3737.284399     1
# Col3a1     9.363615     2
# Col1a2     3.128645     3
# Col4a1     2.269822     4
# Cxcl12     1.914578     5
# Foxp2      1.672987     6
# Hba-a2     1.563326     7
# Hbb-y      1.481038     8
# Hba-a1     1.473053     9
# Hba-x      1.443725    10
#
# Top 10 KO Responsive Genes for Actn1:
#                dis  rank
# Actn1   542.428654     1
# Col3a1    2.789334     2
# Fbn2      1.582850     3
# Lgals1    1.500169     4
# Cnn2      1.034177     5
# Hba-a2    0.986208     6
# Col4a1    0.953604     7
# Vcan      0.925915     8
# Col1a1    0.901832     9
# Hbb-y     0.893394    10
#
# Top 10 KO Responsive Genes for Acvr2b:
#                   dis  rank
# Acvr2b   71228.365432     1
# Col3a1      10.183204     2
# Fbn2         4.689621     3
# Hbb-y        4.116543     4
# Cnn2         3.948414     5
# Rbp1         3.847355     6
# Hbb-bh1      3.632207     7
# Hba-a2       3.186872     8
# Hba-x        3.030815     9
# Hba-a1       2.818607    10
#
# Top 10 KO Responsive Genes for Adam10:
#                     dis  rank
# Adam10         4.154855     1
# 1810037I17Rik  0.000000     2
# Pax1           0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdgfa          0.000000    10
#
# Top 10 KO Responsive Genes for Adamts1:
#                 dis  rank
# Adamts1  236.045015     1
# Col3a1     0.142598     2
# Col1a2     0.052311     3
# Vcan       0.046605     4
# Hba-a2     0.045098     5
# Fbn2       0.043657     6
# Hba-a1     0.042675     7
# Hbb-y      0.042618     8
# Col4a1     0.041833     9
# Hba-x      0.040006    10
#
# Top 10 KO Responsive Genes for Adamts18:
#                    dis  rank
# Adamts18  37032.927154     1
# Hba-a2        1.717607     2
# Hba-a1        1.600327     3
# Hbb-y         1.592393     4
# Hbb-bh1       1.418920     5
# Hba-x         1.385771     6
# Glra1         0.701895     7
# Ednrb         0.485209     8
# Msx3          0.435953     9
# Sox9          0.373977    10
#
# Top 10 KO Responsive Genes for Adamtsl1:
#                    dis  rank
# Adamtsl1  25170.635837     1
# Col3a1        2.737337     2
# Pak3          2.643673     3
# Fbn2          2.112303     4
# Crabp1        2.094149     5
# Gpc3          2.017110     6
# Ptprz1        1.944056     7
# Cnn2          1.889687     8
# Rbp1          1.829296     9
# Glra1         1.755572    10
#
# Top 10 KO Responsive Genes for Adgrl2:
#                   dis  rank
# Adgrl2   25481.777083     1
# Col3a1       3.564951     2
# Gm11263      1.540666     3
# Hba-a2       1.526088     4
# Hba-x        1.510676     5
# Glra1        1.476612     6
# Hba-a1       1.384221     7
# Hbb-y        1.316279     8
# Hbb-bh1      1.245674     9
# Ednrb        1.141526    10
#
# Top 10 KO Responsive Genes for Adgrv1:
#                  dis  rank
# Adgrv1  47128.345629     1
# Pak3        3.893387     2
# Ptprz1      2.996709     3
# Lhx2        2.376192     4
# Crabp1      2.311837     5
# Col3a1      2.225516     6
# Gpc3        2.165428     7
# Ednrb       2.011487     8
# Glra1       1.777745     9
# Nr2e1       1.679470    10
#
# Top 10 KO Responsive Genes for Afap1:
#                  dis  rank
# Afap1    4654.341387     1
# Pak3        0.679428     2
# Rbp1        0.657569     3
# Hba-a2      0.641280     4
# Hba-a1      0.636722     5
# Hbb-y       0.635417     6
# Hbb-bh1     0.601913     7
# Hba-x       0.584910     8
# Meis1       0.511942     9
# Col3a1      0.412380    10
#
# Top 10 KO Responsive Genes for Aff3:
#                dis  rank
# Aff3    522.458630     1
# Crabp1    1.732813     2
# Ptprz1    1.609474     3
# Lgals1    1.518545     4
# Rbp1      1.473678     5
# Lhx2      1.351032     6
# Cxcl12    1.250554     7
# Meis1     1.236062     8
# Nr2e1     1.154585     9
# Wnt8b     1.149606    10
#
# Top 10 KO Responsive Genes for Afg3l1:
#               dis  rank
# Afg3l1  27.912537     1
# Pak3     0.388898     2
# Ptprz1   0.290315     3
# Lhx2     0.255455     4
# Foxg1    0.221290     5
# Nr2e1    0.211264     6
# Igfbp5   0.163761     7
# Id4      0.139040     8
# Six3     0.133589     9
# Dlk1     0.102330    10
#
# Top 10 KO Responsive Genes for Ahnak:
#                   dis  rank
# Ahnak    14248.824822     1
# Col3a1      17.615609     2
# Fbn2        12.044115     3
# Cnn2        11.062164     4
# Hba-a2      10.511051     5
# Hbb-y       10.094693     6
# Hba-a1      10.004679     7
# Hbb-bh1      9.560887     8
# Hba-x        9.334317     9
# Col1a2       9.227271    10
#
# Top 10 KO Responsive Genes for Akap7:
#                     dis  rank
# Akap7          0.102804     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax9           0.000000     4
# Pbx3           0.000000     5
# Pcdh19         0.000000     6
# Pcm1           0.000000     7
# Pcolce         0.000000     8
# Pdhb           0.000000     9
# Pax3           0.000000    10
#
# Top 10 KO Responsive Genes for Aldh1a3:
#                 dis  rank
# Aldh1a3  744.054035     1
# Col3a1     2.279015     2
# Fbn2       2.170234     3
# Gpc3       1.954549     4
# Rbp1       1.487177     5
# Cnn2       1.451025     6
# Hba-a2     1.412088     7
# Hba-a1     1.321969     8
# Pak3       1.319213     9
# Hba-x      1.272956    10
#
# Top 10 KO Responsive Genes for Alx1:
#                 dis  rank
# Alx1    3527.632325     1
# Col3a1    16.214081     2
# Gpc3       9.693448     3
# Col1a2     9.301757     4
# Cxcl12     8.778417     5
# Rbp1       7.084529     6
# Foxp2      6.484980     7
# Lgals1     6.289413     8
# Crabp1     5.690279     9
# Fbn2       5.476006    10
#
# Top 10 KO Responsive Genes for Alx3:
#                dis  rank
# Alx3    564.653269     1
# Fbn2      0.516615     2
# Cnn2      0.447896     3
# Crabp1    0.254035     4
# Rbp1      0.244887     5
# Vcan      0.234381     6
# Pak3      0.203300     7
# Ptprz1    0.198853     8
# Col9a1    0.192016     9
# Col1a1    0.190751    10
#
# Top 10 KO Responsive Genes for Amotl1:
#                dis  rank
# Amotl1  416.644091     1
# Col3a1    3.630430     2
# Fbn2      2.453440     3
# Gpc3      1.939656     4
# Rbp1      1.912227     5
# Col1a2    1.844686     6
# Lgals1    1.638023     7
# Cxcl12    1.293713     8
# Foxp2     1.162404     9
# Foxc1     1.142593    10
#
# Top 10 KO Responsive Genes for Anapc13:
#                 dis  rank
# Anapc13  127.916695     1
# Col3a1     0.024971     2
# Hba-a2     0.015014     3
# Hbb-y      0.013828     4
# Pak3       0.013810     5
# Hba-x      0.013631     6
# Fbn2       0.013462     7
# Hba-a1     0.013192     8
# Hbb-bh1    0.012872     9
# Crabp1     0.010957    10
#
# Top 10 KO Responsive Genes for Angptl2:
#                 dis  rank
# Angptl2  107.551865     1
# Foxg1      0.107955     2
# Gpc3       0.103139     3
# Rbp1       0.086679     4
# Igfbp5     0.063377     5
# Sox9       0.054243     6
# Prrx1      0.053422     7
# Col2a1     0.051354     8
# Adgrl2     0.049543     9
# Gm11263    0.047608    10
#
# Top 10 KO Responsive Genes for Ank2:
#                   dis  rank
# Ank2     12841.108854     1
# Col3a1       0.611327     2
# Hba-x        0.576007     3
# Hba-a2       0.565734     4
# Hbb-y        0.534138     5
# Hba-a1       0.510081     6
# Ednrb        0.483922     7
# Hbb-bh1      0.483639     8
# Glra1        0.439602     9
# Gpc3         0.333406    10
#
# Top 10 KO Responsive Genes for Ank3:
#                   dis  rank
# Ank3     74617.809538     1
# Col3a1       4.839990     2
# Pak3         3.047310     3
# Lhx2         2.378218     4
# Stmn2        2.058562     5
# Onecut2      1.950604     6
# Dcx          1.871976     7
# Nefm         1.677439     8
# Map2         1.635008     9
# Nefl         1.599705    10
#
# Top 10 KO Responsive Genes for Ankrd1:
#                 dis  rank
# Ankrd1  5515.840118     1
# Col3a1     6.895239     2
# Fbn2       5.307789     3
# Gpc3       5.239367     4
# Cnn2       3.535572     5
# Lgals1     3.456920     6
# Hba-a2     3.372386     7
# Hbb-y      3.209245     8
# Hba-a1     3.179140     9
# Hba-x      3.121764    10
#
# Top 10 KO Responsive Genes for Anp32a:
#                 dis  rank
# Anp32a   307.021239     1
# Col3a1     0.173247     2
# Ednrb      0.118059     3
# Hba-a2     0.115815     4
# Hbb-y      0.114183     5
# Hba-x      0.109016     6
# Hbb-bh1    0.104593     7
# Hba-a1     0.103955     8
# Nefl       0.075161     9
# Nefm       0.072287    10
#
# Top 10 KO Responsive Genes for Anxa2:
#                 dis  rank
# Anxa2   4119.026333     1
# Col3a1    19.249149     2
# Fbn2      13.059176     3
# Cnn2      11.341933     4
# Gpc3      10.558308     5
# Col1a2    10.220284     6
# Lgals1     9.023840     7
# Col4a1     8.922727     8
# Hba-a2     8.812636     9
# Hba-a1     8.364238    10
#
# Top 10 KO Responsive Genes for Ap1s2:
#                dis  rank
# Ap1s2    29.843313     1
# Nefl      2.510844     2
# Nefm      2.448505     3
# Ina       2.128530     4
# Gap43     2.127410     5
# Stmn2     1.965431     6
# Onecut2   1.917218     7
# Dcx       1.898765     8
# Elavl3    1.527959     9
# Elavl4    1.250174    10
#
# Top 10 KO Responsive Genes for Ap2s1:
#                 dis  rank
# Ap2s1   1974.515630     1
# Fbn2       2.180936     2
# Gpc3       1.668108     3
# Cnn2       1.604049     4
# Col4a1     1.544728     5
# Col3a1     1.537830     6
# Cxcl12     1.454871     7
# Hba-a2     1.346261     8
# Hbb-y      1.233644     9
# Hba-a1     1.225825    10
#
# Top 10 KO Responsive Genes for Apod:
#                 dis  rank
# Apod     365.679227     1
# Col3a1     2.630464     2
# Hba-a2     2.140097     3
# Hba-x      2.085527     4
# Hbb-y      2.051847     5
# Hba-a1     2.033527     6
# Hbb-bh1    1.946541     7
# Crabp1     1.573206     8
# Col4a1     1.228524     9
# Foxp2      1.001512    10
#
# Top 10 KO Responsive Genes for Apoe:
#                  dis  rank
# Apoe    10535.461840     1
# Col3a1      5.226852     2
# Gpc3        3.328887     3
# Col1a2      3.121435     4
# Fbn2        2.923371     5
# Hba-a2      2.825627     6
# Lgals1      2.740049     7
# Hba-a1      2.689594     8
# Hbb-y       2.672352     9
# Hba-x       2.580793    10
#
# Top 10 KO Responsive Genes for Arf5:
#                dis  rank
# Arf5    519.913113     1
# Col3a1    0.795772     2
# Rbp1      0.715641     3
# Crabp1    0.667021     4
# Cxcl12    0.642761     5
# Foxg1     0.573455     6
# Foxp2     0.485610     7
# Col1a2    0.452659     8
# Prrx1     0.417606     9
# Col2a1    0.402451    10
#
# Top 10 KO Responsive Genes for Arhgap1:
#                  dis  rank
# Arhgap1  4443.479156     1
# Col3a1      2.728484     2
# Fbn2        2.015525     3
# Crabp1      1.894933     4
# Ptprz1      1.779046     5
# Cnn2        1.730002     6
# Rbp1        1.695607     7
# Gpc3        1.596309     8
# Col1a2      1.474314     9
# Meis1       1.422393    10
#
# Top 10 KO Responsive Genes for Arhgap11a:
#                   dis  rank
# Arhgap11a  575.839814     1
# Pak3         6.441307     2
# Hba-a2       6.273462     3
# Hba-x        5.961677     4
# Glra1        4.942085     5
# Ptprz1       4.844820     6
# Ednrb        4.740599     7
# Rbp1         4.604595     8
# Msx3         4.371586     9
# Lhx2         4.120558    10
#
# Top 10 KO Responsive Genes for Arhgap35:
#                 dis  rank
# Arhgap35  39.818624     1
# Col3a1     7.151018     2
# Pak3       4.687761     3
# Fbn2       4.615629     4
# Hbb-y      4.308236     5
# Hbb-bh1    4.026183     6
# Cnn2       3.978102     7
# Ptprz1     3.696736     8
# Kif21a     1.815472     9
# Acvr2b     1.564226    10
#
# Top 10 KO Responsive Genes for Arx:
#                  dis  rank
# Arx     53460.200026     1
# Pak3        1.424630     2
# Col3a1      1.237352     3
# Ptprz1      1.158467     4
# Hba-a2      1.085083     5
# Lhx2        1.062990     6
# Hba-x       1.060296     7
# Hba-a1      1.059608     8
# Wnt8b       0.987579     9
# Nr2e1       0.947550    10
#
# Top 10 KO Responsive Genes for Atp1b1:
#                 dis  rank
# Atp1b1  7265.730074     1
# Crabp1     1.515369     2
# Fbn2       1.376835     3
# Gpc3       1.061001     4
# Cnn2       0.988539     5
# Vcan       0.937891     6
# Glra1      0.752401     7
# Ednrb      0.708491     8
# Msx3       0.699918     9
# Lgals1     0.679945    10
#
# Top 10 KO Responsive Genes for Bach2:
#                  dis  rank
# Bach2   35759.854312     1
# Pak3        1.883711     2
# Fbn2        0.995844     3
# Cnn2        0.806297     4
# Ptprz1      0.719084     5
# Wnt4        0.664625     6
# Rarb        0.648827     7
# Gpc3        0.596923     8
# Nr2e1       0.477463     9
# Col1a2      0.473539    10
#
# Top 10 KO Responsive Genes for Barhl2:
#              dis  rank
# Barhl2  6.097080     1
# Foxg1   0.018793     2
# Col3a1  0.014993     3
# Fbn2    0.013607     4
# Cnn2    0.011207     5
# Nr2e1   0.010992     6
# Glra1   0.009850     7
# Gpc3    0.009576     8
# Ednrb   0.009130     9
# Hoxa5   0.008712    10
#
# Top 10 KO Responsive Genes for Bcl11a:
#                   dis  rank
# Bcl11a   32316.707604     1
# Col3a1       7.542814     2
# Pak3         4.951142     3
# Ptprz1       4.751758     4
# Ednrb        4.172434     5
# Hbb-y        3.956017     6
# Hba-a2       3.901634     7
# Hba-x        3.711940     8
# Hbb-bh1      3.486477     9
# Hba-a1       3.471853    10
#
# Top 10 KO Responsive Genes for Bcl11b:
#                  dis  rank
# Bcl11b   4341.620037     1
# Col3a1      1.481565     2
# Ednrb       0.756320     3
# Msx3        0.736620     4
# Hba-x       0.704497     5
# Hba-a2      0.681804     6
# Hba-a1      0.626275     7
# Hbb-y       0.539354     8
# Gpc3        0.536088     9
# Hbb-bh1     0.528903    10
#
# Top 10 KO Responsive Genes for Bex1:
#                dis  rank
# Bex1    557.324121     1
# Col3a1    0.956783     2
# Fbn2      0.617751     3
# Pak3      0.593440     4
# Cnn2      0.546815     5
# Vcan      0.457439     6
# Nefl      0.423900     7
# Nefm      0.420741     8
# Ptprz1    0.408261     9
# Gap43     0.389632    10
#
# Top 10 KO Responsive Genes for Bicc1:
#                 dis  rank
# Bicc1   4327.677804     1
# Col3a1     8.234847     2
# Fbn2       6.025378     3
# Pak3       5.345926     4
# Cnn2       5.304789     5
# Gpc3       4.998327     6
# Ptprz1     4.821217     7
# Crabp1     4.725719     8
# Col1a2     4.484758     9
# Lgals1     4.215148    10
#
# Top 10 KO Responsive Genes for Bri3:
#                dis  rank
# Bri3     54.514325     1
# Hba-a2    0.012187     2
# Hba-x     0.011348     3
# Col3a1    0.011198     4
# Hbb-y     0.011196     5
# Pak3      0.010846     6
# Hba-a1    0.010770     7
# Hbb-bh1   0.010486     8
# Gpc3      0.007429     9
# Ttn       0.007409    10
#
# Top 10 KO Responsive Genes for Btg1:
#                  dis  rank
# Btg1     7667.453251     1
# Hba-a2      6.948627     2
# Hbb-y       6.717229     3
# Hba-a1      6.672599     4
# Hba-x       6.595197     5
# Col3a1      6.515454     6
# Hbb-bh1     6.313579     7
# Rbp1        4.987074     8
# Glra1       4.934749     9
# Ednrb       4.584181    10

# %% [markdown]
# ### Validate the difference by choosing the different genes

# %%
## 1. Use SEED for reproducibility to validate

# Step 1: Select the genes to knock out
genes_of_interest = adata.var.index[:50].tolist()
print(f"Genes to knock out: {genes_of_interest}")

# Step 2: Choose two dummy genes
all_genes = list(adata.var.index)
dummy_genes = [g for g in all_genes if g not in genes_of_interest][:2]  # Select the first 2 dummy genes
dummy_gene1, dummy_gene2 = dummy_genes
print(f"Dummy genes selected: {dummy_gene1}, {dummy_gene2}")

# Set random seeds for reproducibility
import numpy as np
import random
import torch

SEED = 8096
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Define the function to run KO experiments
def run_ko_with_dummy(dummy_gene, genes_of_interest):

    print(f"\nRunning KO experiments with dummy gene: {dummy_gene}")

    # Initialize DataLoader for WT data
    data_wrapper_wt = DataLoader(
        adata,
        target_gene=[dummy_gene],
        target_cell=None,
        obs_label="cell_type",  # Adjust if necessary
        GRN_file_dir="GRNs",
        rebuild_GRN=True,  # Build the GRN
        pcNet_name=f"DBiTseq_example_{dummy_gene}",
        verbose=False,
        n_cpus=8,
    )

    # Load WT data (GRN will be built here)
    data_wt = data_wrapper_wt.load_data()

    # Set hyperparameters
    hyperparams = {
        "epochs": 300,
        "lr": 5e-2,
        "beta": 5e-4,
        "seed": SEED,
    }

    # Train the model on WT data
    sensei = VGAE_trainer(
        data_wt,
        epochs=hyperparams["epochs"],
        lr=hyperparams["lr"],
        beta=hyperparams["beta"],
        seed=hyperparams["seed"],
        verbose=False,
    )

    sensei.train()

    # Get latent variables for WT data
    z_mu_wt, z_std_wt = sensei.get_latent_vars(data_wt)

    # Initialize a dictionary to store results
    top_responsive_genes = {}

    for gene_of_interest in genes_of_interest:
        # Initialize DataLoader for KO data
        data_wrapper_ko = DataLoader(
            adata,
            target_gene=[gene_of_interest],
            target_cell=None,
            obs_label="cell_type",
            GRN_file_dir="GRNs",
            rebuild_GRN=False,  # Use the existing GRN
            pcNet_name=f"DBiTseq_example_{dummy_gene}",
            verbose=False,
            n_cpus=8,
        )

        # Load KO data for the gene
        data_ko = data_wrapper_ko.load_kodata()

        # Get latent variables for KO data
        z_mu_ko, z_std_ko = sensei.get_latent_vars(data_ko)

        # Calculate the distance between WT and KO data
        dis = gk.utils.get_distance(z_mu_ko, z_std_ko, z_mu_wt, z_std_wt, by="KL")

        # Get the ranked list of responsive genes
        res_raw = utils.get_generank(data_wt, dis, rank=True)

        # Store the top 10 responsive genes
        top_genes = res_raw.head(10)
        top_responsive_genes[gene_of_interest] = top_genes

    return top_responsive_genes

# Run KO experiments with each dummy gene
results_dummy1 = run_ko_with_dummy(dummy_gene1, genes_of_interest)
results_dummy2 = run_ko_with_dummy(dummy_gene2, genes_of_interest)

# Compare the results
def compare_ko_results(results1, results2, genes_of_interest):
    differences = {}

    for gene in genes_of_interest:
        top_genes1 = results1[gene].index.tolist()
        top_genes2 = results2[gene].index.tolist()
        if top_genes1 != top_genes2:
            differences[gene] = {
                'dummy_gene1_top_genes': top_genes1,
                'dummy_gene2_top_genes': top_genes2,
            }

    return differences

differences = compare_ko_results(results_dummy1, results_dummy2, genes_of_interest)

# Print out the differences
if differences:
    print("\nDifferences found in top responsive genes between the two dummy genes:")
    for gene, diff in differences.items():
        print(f"\nGene {gene}:")
        print(f"Top genes with dummy gene {dummy_gene1}: {diff['dummy_gene1_top_genes']}")
        print(f"Top genes with dummy gene {dummy_gene2}: {diff['dummy_gene2_top_genes']}")
else:
    print("\nNo differences found in top responsive genes between the two dummy genes.")
# Out:
# Genes to knock out: ['1810037I17Rik', '2410002F23Rik', '5730559C18Rik', 'Aagab', 'Aars2', 'Acat1', 'Acta2', 'Actc1', 'Actn1', 'Acvr2b', 'Adam10', 'Adamts1', 'Adamts18', 'Adamtsl1', 'Adgrl2', 'Adgrv1', 'Afap1', 'Aff3', 'Afg3l1', 'Ahnak', 'Akap7', 'Aldh1a3', 'Alx1', 'Alx3', 'Amotl1', 'Anapc13', 'Angptl2', 'Ank2', 'Ank3', 'Ankrd1', 'Anp32a', 'Anxa2', 'Ap1s2', 'Ap2s1', 'Apod', 'Apoe', 'Arf5', 'Arhgap1', 'Arhgap11a', 'Arhgap35', 'Arx', 'Atp1b1', 'Bach2', 'Barhl2', 'Bcl11a', 'Bcl11b', 'Bex1', 'Bicc1', 'Bri3', 'Btg1']
# Dummy genes selected: Bub3, C130093G08Rik
#
# Running KO experiments with dummy gene: Bub3
# 2024-10-31 09:44:48,334	INFO worker.py:1816 -- Started a local Ray instance.
# ray init, using 8 CPUs
#
# Running KO experiments with dummy gene: C130093G08Rik
# 2024-10-31 09:48:44,631	INFO worker.py:1816 -- Started a local Ray instance.
# ray init, using 8 CPUs
#
# No differences found in top responsive genes between the two dummy genes.

# %%
## 2. Manually change to another dummy gene to validate


# Get the first 50 genes in adata.var.index
genes_of_interest = adata.var.index[:50].tolist()
print(f"Genes to knock out: {genes_of_interest}")

# Set 'Eya1' as the dummy gene
dummy_gene = 'Eya1'
print(f"Using dummy gene for WT data: {dummy_gene}")

# Verify that 'Eya1' is not in genes_of_interest
if dummy_gene in genes_of_interest:
    raise ValueError(f"The dummy gene '{dummy_gene}' is in the genes of interest. Please choose a different dummy gene.")

# Initialize DataLoader for WT data
data_wrapper_wt = DataLoader(
    adata,
    target_gene=[dummy_gene],  # Use 'Eya1' as the dummy gene
    target_cell=None,
    obs_label="cell_type",  # Adjust if necessary
    GRN_file_dir="GRNs",
    rebuild_GRN=True,  # Build the GRN
    pcNet_name="DBiTseq_example_Eya1",
    verbose=False,  # Set to False to reduce output
    n_cpus=8,
)

# Load WT data (GRN will be built here)
data_wt = data_wrapper_wt.load_data()

# Set hyperparameters
hyperparams = {
    "epochs": 300,
    "lr": 5e-2,
    "beta": 5e-4,
    "seed": 8096,
}

# Train the model on WT data
sensei = VGAE_trainer(
    data_wt,
    epochs=hyperparams["epochs"],
    lr=hyperparams["lr"],
    beta=hyperparams["beta"],
    seed=hyperparams["seed"],
    verbose=False,  # Set to False to reduce output
)

sensei.train()

# Get latent variables for WT data
z_mu_wt, z_std_wt = sensei.get_latent_vars(data_wt)

# Initialize a dictionary to store results
top_responsive_genes = {}

for gene_of_interest in genes_of_interest:
    print(f"\nProcessing gene: {gene_of_interest}")

    # Initialize DataLoader for KO data
    data_wrapper_ko = DataLoader(
        adata,
        target_gene=[gene_of_interest],
        target_cell=None,
        obs_label="cell_type",
        GRN_file_dir="GRNs",
        rebuild_GRN=False,  # Use the existing GRN
        pcNet_name="DBiTseq_example_Eya1",
        verbose=False,  # Set to False to reduce output
        n_cpus=8,
    )

    # Load KO data for the gene
    data_ko = data_wrapper_ko.load_kodata()

    # Get latent variables for KO data
    z_mu_ko, z_std_ko = sensei.get_latent_vars(data_ko)

    # Calculate the distance between WT and KO data
    dis = gk.utils.get_distance(z_mu_ko, z_std_ko, z_mu_wt, z_std_wt, by="KL")

    # Get the ranked list of responsive genes
    res_raw = utils.get_generank(data_wt, dis, rank=True)

    # Store the top 10 responsive genes
    top_genes = res_raw.head(10)
    top_responsive_genes[gene_of_interest] = top_genes

# Display the results
for gene, df in top_responsive_genes.items():
    print(f"\nTop 10 KO Responsive Genes for {gene}:")
    print(df)
# Out:
# Genes to knock out: ['1810037I17Rik', '2410002F23Rik', '5730559C18Rik', 'Aagab', 'Aars2', 'Acat1', 'Acta2', 'Actc1', 'Actn1', 'Acvr2b', 'Adam10', 'Adamts1', 'Adamts18', 'Adamtsl1', 'Adgrl2', 'Adgrv1', 'Afap1', 'Aff3', 'Afg3l1', 'Ahnak', 'Akap7', 'Aldh1a3', 'Alx1', 'Alx3', 'Amotl1', 'Anapc13', 'Angptl2', 'Ank2', 'Ank3', 'Ankrd1', 'Anp32a', 'Anxa2', 'Ap1s2', 'Ap2s1', 'Apod', 'Apoe', 'Arf5', 'Arhgap1', 'Arhgap11a', 'Arhgap35', 'Arx', 'Atp1b1', 'Bach2', 'Barhl2', 'Bcl11a', 'Bcl11b', 'Bex1', 'Bicc1', 'Bri3', 'Btg1']
# Using dummy gene for WT data: Eya1
# 2024-10-31 10:09:22,927	INFO worker.py:1816 -- Started a local Ray instance.
# ray init, using 8 CPUs
#
# Processing gene: 1810037I17Rik
#
# Processing gene: 2410002F23Rik
#
# Processing gene: 5730559C18Rik
#
# Processing gene: Aagab
#
# Processing gene: Aars2
#
# Processing gene: Acat1
#
# Processing gene: Acta2
#
# Processing gene: Actc1
#
# Processing gene: Actn1
#
# Processing gene: Acvr2b
#
# Processing gene: Adam10
#
# Processing gene: Adamts1
#
# Processing gene: Adamts18
#
# Processing gene: Adamtsl1
#
# Processing gene: Adgrl2
#
# Processing gene: Adgrv1
#
# Processing gene: Afap1
#
# Processing gene: Aff3
#
# Processing gene: Afg3l1
#
# Processing gene: Ahnak
#
# Processing gene: Akap7
#
# Processing gene: Aldh1a3
#
# Processing gene: Alx1
#
# Processing gene: Alx3
#
# Processing gene: Amotl1
#
# Processing gene: Anapc13
#
# Processing gene: Angptl2
#
# Processing gene: Ank2
#
# Processing gene: Ank3
#
# Processing gene: Ankrd1
#
# Processing gene: Anp32a
#
# Processing gene: Anxa2
#
# Processing gene: Ap1s2
#
# Processing gene: Ap2s1
#
# Processing gene: Apod
#
# Processing gene: Apoe
#
# Processing gene: Arf5
#
# Processing gene: Arhgap1
#
# Processing gene: Arhgap11a
#
# Processing gene: Arhgap35
#
# Processing gene: Arx
#
# Processing gene: Atp1b1
#
# Processing gene: Bach2
#
# Processing gene: Barhl2
#
# Processing gene: Bcl11a
#
# Processing gene: Bcl11b
#
# Processing gene: Bex1
#
# Processing gene: Bicc1
#
# Processing gene: Bri3
#
# Processing gene: Btg1
#
# Top 10 KO Responsive Genes for 1810037I17Rik:
#                      dis  rank
# 1810037I17Rik  72.716254     1
# Col3a1          0.045720     2
# Col1a2          0.027975     3
# Bcl11a          0.026990     4
# Fbn2            0.021538     5
# Sox9            0.020365     6
# Meis1           0.020127     7
# Gm11263         0.019654     8
# Foxp2           0.018440     9
# Id2             0.017870    10
#
# Top 10 KO Responsive Genes for 2410002F23Rik:
#                     dis  rank
# 2410002F23Rik  0.003002     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for 5730559C18Rik:
#                     dis  rank
# 5730559C18Rik  0.054792     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for Aagab:
#              dis  rank
# Pak3    2.210185     1
# Aagab   0.335850     2
# Col3a1  0.003313     3
# Ptprz1  0.002357     4
# Fbn2    0.002146     5
# Lhx2    0.001898     6
# Cnn2    0.001790     7
# Gpc3    0.001615     8
# Glra1   0.001569     9
# Col1a2  0.001495    10
#
# Top 10 KO Responsive Genes for Aars2:
#                     dis  rank
# Aars2          0.003002     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for Acat1:
#                     dis  rank
# Acat1          5.785017     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdhb           0.000000    10
#
# Top 10 KO Responsive Genes for Acta2:
#                   dis  rank
# Acta2    11424.605817     1
# Hba-x        0.918715     2
# Hba-a2       0.885070     3
# Hbb-y        0.867944     4
# Hba-a1       0.846784     5
# Hbb-bh1      0.806567     6
# Igfbp5       0.609059     7
# Gpc3         0.557601     8
# Vcan         0.443747     9
# Rbp1         0.440497    10
#
# Top 10 KO Responsive Genes for Actc1:
#                 dis  rank
# Actc1   3737.284399     1
# Col3a1     9.363615     2
# Col1a2     3.128645     3
# Col4a1     2.269822     4
# Cxcl12     1.914578     5
# Foxp2      1.672987     6
# Hba-a2     1.563326     7
# Hbb-y      1.481038     8
# Hba-a1     1.473053     9
# Hba-x      1.443725    10
#
# Top 10 KO Responsive Genes for Actn1:
#                dis  rank
# Actn1   542.428654     1
# Col3a1    2.789334     2
# Fbn2      1.582850     3
# Lgals1    1.500169     4
# Cnn2      1.034177     5
# Hba-a2    0.986208     6
# Col4a1    0.953604     7
# Vcan      0.925915     8
# Col1a1    0.901832     9
# Hbb-y     0.893394    10
#
# Top 10 KO Responsive Genes for Acvr2b:
#                   dis  rank
# Acvr2b   71228.365432     1
# Col3a1      10.183204     2
# Fbn2         4.689621     3
# Hbb-y        4.116543     4
# Cnn2         3.948414     5
# Rbp1         3.847355     6
# Hbb-bh1      3.632207     7
# Hba-a2       3.186872     8
# Hba-x        3.030815     9
# Hba-a1       2.818607    10
#
# Top 10 KO Responsive Genes for Adam10:
#                     dis  rank
# Adam10         4.154855     1
# 1810037I17Rik  0.000000     2
# Pax1           0.000000     3
# Pax5           0.000000     4
# Pax9           0.000000     5
# Pbx3           0.000000     6
# Pcdh19         0.000000     7
# Pcm1           0.000000     8
# Pcolce         0.000000     9
# Pdgfa          0.000000    10
#
# Top 10 KO Responsive Genes for Adamts1:
#                 dis  rank
# Adamts1  236.045015     1
# Col3a1     0.142598     2
# Col1a2     0.052311     3
# Vcan       0.046605     4
# Hba-a2     0.045098     5
# Fbn2       0.043657     6
# Hba-a1     0.042675     7
# Hbb-y      0.042618     8
# Col4a1     0.041833     9
# Hba-x      0.040006    10
#
# Top 10 KO Responsive Genes for Adamts18:
#                    dis  rank
# Adamts18  37032.927154     1
# Hba-a2        1.717607     2
# Hba-a1        1.600327     3
# Hbb-y         1.592393     4
# Hbb-bh1       1.418920     5
# Hba-x         1.385771     6
# Glra1         0.701895     7
# Ednrb         0.485209     8
# Msx3          0.435953     9
# Sox9          0.373977    10
#
# Top 10 KO Responsive Genes for Adamtsl1:
#                    dis  rank
# Adamtsl1  25170.635837     1
# Col3a1        2.737337     2
# Pak3          2.643673     3
# Fbn2          2.112303     4
# Crabp1        2.094149     5
# Gpc3          2.017110     6
# Ptprz1        1.944056     7
# Cnn2          1.889687     8
# Rbp1          1.829296     9
# Glra1         1.755572    10
#
# Top 10 KO Responsive Genes for Adgrl2:
#                   dis  rank
# Adgrl2   25481.777083     1
# Col3a1       3.564951     2
# Gm11263      1.540666     3
# Hba-a2       1.526088     4
# Hba-x        1.510676     5
# Glra1        1.476612     6
# Hba-a1       1.384221     7
# Hbb-y        1.316279     8
# Hbb-bh1      1.245674     9
# Ednrb        1.141526    10
#
# Top 10 KO Responsive Genes for Adgrv1:
#                  dis  rank
# Adgrv1  47128.345629     1
# Pak3        3.893387     2
# Ptprz1      2.996709     3
# Lhx2        2.376192     4
# Crabp1      2.311837     5
# Col3a1      2.225516     6
# Gpc3        2.165428     7
# Ednrb       2.011487     8
# Glra1       1.777745     9
# Nr2e1       1.679470    10
#
# Top 10 KO Responsive Genes for Afap1:
#                  dis  rank
# Afap1    4654.341387     1
# Pak3        0.679428     2
# Rbp1        0.657569     3
# Hba-a2      0.641280     4
# Hba-a1      0.636722     5
# Hbb-y       0.635417     6
# Hbb-bh1     0.601913     7
# Hba-x       0.584910     8
# Meis1       0.511942     9
# Col3a1      0.412380    10
#
# Top 10 KO Responsive Genes for Aff3:
#                dis  rank
# Aff3    522.458630     1
# Crabp1    1.732813     2
# Ptprz1    1.609474     3
# Lgals1    1.518545     4
# Rbp1      1.473678     5
# Lhx2      1.351032     6
# Cxcl12    1.250554     7
# Meis1     1.236062     8
# Nr2e1     1.154585     9
# Wnt8b     1.149606    10
#
# Top 10 KO Responsive Genes for Afg3l1:
#               dis  rank
# Afg3l1  27.912537     1
# Pak3     0.388898     2
# Ptprz1   0.290315     3
# Lhx2     0.255455     4
# Foxg1    0.221290     5
# Nr2e1    0.211264     6
# Igfbp5   0.163761     7
# Id4      0.139040     8
# Six3     0.133589     9
# Dlk1     0.102330    10
#
# Top 10 KO Responsive Genes for Ahnak:
#                   dis  rank
# Ahnak    14248.824822     1
# Col3a1      17.615609     2
# Fbn2        12.044115     3
# Cnn2        11.062164     4
# Hba-a2      10.511051     5
# Hbb-y       10.094693     6
# Hba-a1      10.004679     7
# Hbb-bh1      9.560887     8
# Hba-x        9.334317     9
# Col1a2       9.227271    10
#
# Top 10 KO Responsive Genes for Akap7:
#                     dis  rank
# Akap7          0.102804     1
# 1810037I17Rik  0.000000     2
# Pdgfa          0.000000     3
# Pax9           0.000000     4
# Pbx3           0.000000     5
# Pcdh19         0.000000     6
# Pcm1           0.000000     7
# Pcolce         0.000000     8
# Pdhb           0.000000     9
# Pax3           0.000000    10
#
# Top 10 KO Responsive Genes for Aldh1a3:
#                 dis  rank
# Aldh1a3  744.054035     1
# Col3a1     2.279015     2
# Fbn2       2.170234     3
# Gpc3       1.954549     4
# Rbp1       1.487177     5
# Cnn2       1.451025     6
# Hba-a2     1.412088     7
# Hba-a1     1.321969     8
# Pak3       1.319213     9
# Hba-x      1.272956    10
#
# Top 10 KO Responsive Genes for Alx1:
#                 dis  rank
# Alx1    3527.632325     1
# Col3a1    16.214081     2
# Gpc3       9.693448     3
# Col1a2     9.301757     4
# Cxcl12     8.778417     5
# Rbp1       7.084529     6
# Foxp2      6.484980     7
# Lgals1     6.289413     8
# Crabp1     5.690279     9
# Fbn2       5.476006    10
#
# Top 10 KO Responsive Genes for Alx3:
#                dis  rank
# Alx3    564.653269     1
# Fbn2      0.516615     2
# Cnn2      0.447896     3
# Crabp1    0.254035     4
# Rbp1      0.244887     5
# Vcan      0.234381     6
# Pak3      0.203300     7
# Ptprz1    0.198853     8
# Col9a1    0.192016     9
# Col1a1    0.190751    10
#
# Top 10 KO Responsive Genes for Amotl1:
#                dis  rank
# Amotl1  416.644091     1
# Col3a1    3.630430     2
# Fbn2      2.453440     3
# Gpc3      1.939656     4
# Rbp1      1.912227     5
# Col1a2    1.844686     6
# Lgals1    1.638023     7
# Cxcl12    1.293713     8
# Foxp2     1.162404     9
# Foxc1     1.142593    10
#
# Top 10 KO Responsive Genes for Anapc13:
#                 dis  rank
# Anapc13  127.916695     1
# Col3a1     0.024971     2
# Hba-a2     0.015014     3
# Hbb-y      0.013828     4
# Pak3       0.013810     5
# Hba-x      0.013631     6
# Fbn2       0.013462     7
# Hba-a1     0.013192     8
# Hbb-bh1    0.012872     9
# Crabp1     0.010957    10
#
# Top 10 KO Responsive Genes for Angptl2:
#                 dis  rank
# Angptl2  107.551865     1
# Foxg1      0.107955     2
# Gpc3       0.103139     3
# Rbp1       0.086679     4
# Igfbp5     0.063377     5
# Sox9       0.054243     6
# Prrx1      0.053422     7
# Col2a1     0.051354     8
# Adgrl2     0.049543     9
# Gm11263    0.047608    10
#
# Top 10 KO Responsive Genes for Ank2:
#                   dis  rank
# Ank2     12841.108854     1
# Col3a1       0.611327     2
# Hba-x        0.576007     3
# Hba-a2       0.565734     4
# Hbb-y        0.534138     5
# Hba-a1       0.510081     6
# Ednrb        0.483922     7
# Hbb-bh1      0.483639     8
# Glra1        0.439602     9
# Gpc3         0.333406    10
#
# Top 10 KO Responsive Genes for Ank3:
#                   dis  rank
# Ank3     74617.809538     1
# Col3a1       4.839990     2
# Pak3         3.047310     3
# Lhx2         2.378218     4
# Stmn2        2.058562     5
# Onecut2      1.950604     6
# Dcx          1.871976     7
# Nefm         1.677439     8
# Map2         1.635008     9
# Nefl         1.599705    10
#
# Top 10 KO Responsive Genes for Ankrd1:
#                 dis  rank
# Ankrd1  5515.840118     1
# Col3a1     6.895239     2
# Fbn2       5.307789     3
# Gpc3       5.239367     4
# Cnn2       3.535572     5
# Lgals1     3.456920     6
# Hba-a2     3.372386     7
# Hbb-y      3.209245     8
# Hba-a1     3.179140     9
# Hba-x      3.121764    10
#
# Top 10 KO Responsive Genes for Anp32a:
#                 dis  rank
# Anp32a   307.021239     1
# Col3a1     0.173247     2
# Ednrb      0.118059     3
# Hba-a2     0.115815     4
# Hbb-y      0.114183     5
# Hba-x      0.109016     6
# Hbb-bh1    0.104593     7
# Hba-a1     0.103955     8
# Nefl       0.075161     9
# Nefm       0.072287    10
#
# Top 10 KO Responsive Genes for Anxa2:
#                 dis  rank
# Anxa2   4119.026333     1
# Col3a1    19.249149     2
# Fbn2      13.059176     3
# Cnn2      11.341933     4
# Gpc3      10.558308     5
# Col1a2    10.220284     6
# Lgals1     9.023840     7
# Col4a1     8.922727     8
# Hba-a2     8.812636     9
# Hba-a1     8.364238    10
#
# Top 10 KO Responsive Genes for Ap1s2:
#                dis  rank
# Ap1s2    29.843313     1
# Nefl      2.510844     2
# Nefm      2.448505     3
# Ina       2.128530     4
# Gap43     2.127410     5
# Stmn2     1.965431     6
# Onecut2   1.917218     7
# Dcx       1.898765     8
# Elavl3    1.527959     9
# Elavl4    1.250174    10
#
# Top 10 KO Responsive Genes for Ap2s1:
#                 dis  rank
# Ap2s1   1974.515630     1
# Fbn2       2.180936     2
# Gpc3       1.668108     3
# Cnn2       1.604049     4
# Col4a1     1.544728     5
# Col3a1     1.537830     6
# Cxcl12     1.454871     7
# Hba-a2     1.346261     8
# Hbb-y      1.233644     9
# Hba-a1     1.225825    10
#
# Top 10 KO Responsive Genes for Apod:
#                 dis  rank
# Apod     365.679227     1
# Col3a1     2.630464     2
# Hba-a2     2.140097     3
# Hba-x      2.085527     4
# Hbb-y      2.051847     5
# Hba-a1     2.033527     6
# Hbb-bh1    1.946541     7
# Crabp1     1.573206     8
# Col4a1     1.228524     9
# Foxp2      1.001512    10
#
# Top 10 KO Responsive Genes for Apoe:
#                  dis  rank
# Apoe    10535.461840     1
# Col3a1      5.226852     2
# Gpc3        3.328887     3
# Col1a2      3.121435     4
# Fbn2        2.923371     5
# Hba-a2      2.825627     6
# Lgals1      2.740049     7
# Hba-a1      2.689594     8
# Hbb-y       2.672352     9
# Hba-x       2.580793    10
#
# Top 10 KO Responsive Genes for Arf5:
#                dis  rank
# Arf5    519.913113     1
# Col3a1    0.795772     2
# Rbp1      0.715641     3
# Crabp1    0.667021     4
# Cxcl12    0.642761     5
# Foxg1     0.573455     6
# Foxp2     0.485610     7
# Col1a2    0.452659     8
# Prrx1     0.417606     9
# Col2a1    0.402451    10
#
# Top 10 KO Responsive Genes for Arhgap1:
#                  dis  rank
# Arhgap1  4443.479156     1
# Col3a1      2.728484     2
# Fbn2        2.015525     3
# Crabp1      1.894933     4
# Ptprz1      1.779046     5
# Cnn2        1.730002     6
# Rbp1        1.695607     7
# Gpc3        1.596309     8
# Col1a2      1.474314     9
# Meis1       1.422393    10
#
# Top 10 KO Responsive Genes for Arhgap11a:
#                   dis  rank
# Arhgap11a  575.839814     1
# Pak3         6.441307     2
# Hba-a2       6.273462     3
# Hba-x        5.961677     4
# Glra1        4.942085     5
# Ptprz1       4.844820     6
# Ednrb        4.740599     7
# Rbp1         4.604595     8
# Msx3         4.371586     9
# Lhx2         4.120558    10
#
# Top 10 KO Responsive Genes for Arhgap35:
#                 dis  rank
# Arhgap35  39.818624     1
# Col3a1     7.151018     2
# Pak3       4.687761     3
# Fbn2       4.615629     4
# Hbb-y      4.308236     5
# Hbb-bh1    4.026183     6
# Cnn2       3.978102     7
# Ptprz1     3.696736     8
# Kif21a     1.815472     9
# Acvr2b     1.564226    10
#
# Top 10 KO Responsive Genes for Arx:
#                  dis  rank
# Arx     53460.200026     1
# Pak3        1.424630     2
# Col3a1      1.237352     3
# Ptprz1      1.158467     4
# Hba-a2      1.085083     5
# Lhx2        1.062990     6
# Hba-x       1.060296     7
# Hba-a1      1.059608     8
# Wnt8b       0.987579     9
# Nr2e1       0.947550    10
#
# Top 10 KO Responsive Genes for Atp1b1:
#                 dis  rank
# Atp1b1  7265.730074     1
# Crabp1     1.515369     2
# Fbn2       1.376835     3
# Gpc3       1.061001     4
# Cnn2       0.988539     5
# Vcan       0.937891     6
# Glra1      0.752401     7
# Ednrb      0.708491     8
# Msx3       0.699918     9
# Lgals1     0.679945    10
#
# Top 10 KO Responsive Genes for Bach2:
#                  dis  rank
# Bach2   35759.854312     1
# Pak3        1.883711     2
# Fbn2        0.995844     3
# Cnn2        0.806297     4
# Ptprz1      0.719084     5
# Wnt4        0.664625     6
# Rarb        0.648827     7
# Gpc3        0.596923     8
# Nr2e1       0.477463     9
# Col1a2      0.473539    10
#
# Top 10 KO Responsive Genes for Barhl2:
#              dis  rank
# Barhl2  6.097080     1
# Foxg1   0.018793     2
# Col3a1  0.014993     3
# Fbn2    0.013607     4
# Cnn2    0.011207     5
# Nr2e1   0.010992     6
# Glra1   0.009850     7
# Gpc3    0.009576     8
# Ednrb   0.009130     9
# Hoxa5   0.008712    10
#
# Top 10 KO Responsive Genes for Bcl11a:
#                   dis  rank
# Bcl11a   32316.707604     1
# Col3a1       7.542814     2
# Pak3         4.951142     3
# Ptprz1       4.751758     4
# Ednrb        4.172434     5
# Hbb-y        3.956017     6
# Hba-a2       3.901634     7
# Hba-x        3.711940     8
# Hbb-bh1      3.486477     9
# Hba-a1       3.471853    10
#
# Top 10 KO Responsive Genes for Bcl11b:
#                  dis  rank
# Bcl11b   4341.620037     1
# Col3a1      1.481565     2
# Ednrb       0.756320     3
# Msx3        0.736620     4
# Hba-x       0.704497     5
# Hba-a2      0.681804     6
# Hba-a1      0.626275     7
# Hbb-y       0.539354     8
# Gpc3        0.536088     9
# Hbb-bh1     0.528903    10
#
# Top 10 KO Responsive Genes for Bex1:
#                dis  rank
# Bex1    557.324121     1
# Col3a1    0.956783     2
# Fbn2      0.617751     3
# Pak3      0.593440     4
# Cnn2      0.546815     5
# Vcan      0.457439     6
# Nefl      0.423900     7
# Nefm      0.420741     8
# Ptprz1    0.408261     9
# Gap43     0.389632    10
#
# Top 10 KO Responsive Genes for Bicc1:
#                 dis  rank
# Bicc1   4327.677804     1
# Col3a1     8.234847     2
# Fbn2       6.025378     3
# Pak3       5.345926     4
# Cnn2       5.304789     5
# Gpc3       4.998327     6
# Ptprz1     4.821217     7
# Crabp1     4.725719     8
# Col1a2     4.484758     9
# Lgals1     4.215148    10
#
# Top 10 KO Responsive Genes for Bri3:
#                dis  rank
# Bri3     54.514325     1
# Hba-a2    0.012187     2
# Hba-x     0.011348     3
# Col3a1    0.011198     4
# Hbb-y     0.011196     5
# Pak3      0.010846     6
# Hba-a1    0.010770     7
# Hbb-bh1   0.010486     8
# Gpc3      0.007429     9
# Ttn       0.007409    10
#
# Top 10 KO Responsive Genes for Btg1:
#                  dis  rank
# Btg1     7667.453251     1
# Hba-a2      6.948627     2
# Hbb-y       6.717229     3
# Hba-a1      6.672599     4
# Hba-x       6.595197     5
# Col3a1      6.515454     6
# Hbb-bh1     6.313579     7
# Rbp1        4.987074     8
# Glra1       4.934749     9
# Ednrb       4.584181    10

# %% [markdown]
# ### save for cvs documents

# %%
# Save the outputs

# Import pandas
import pandas as pd

# Prepare a list to hold individual DataFrames
results_list = []

# Iterate over the results for each knocked-out gene
for ko_gene, df in top_responsive_genes.items():
    # Reset the index to turn the gene names from the index into a column
    df = df.reset_index()
    # Add a column for the knocked-out gene
    df['KO_Gene'] = ko_gene
    # Append the DataFrame to the list
    results_list.append(df)

# Concatenate all DataFrames into one
combined_results = pd.concat(results_list, ignore_index=True)

# Rearrange columns for clarity
combined_results = combined_results[['KO_Gene', 'index', 'dis', 'rank']]

# Rename columns for better readability
combined_results.columns = ['KO_Gene', 'Responsive_Gene', 'Distance', 'Rank']

# Save the DataFrame to a CSV file
combined_results.to_csv('top10_KO_responsive_genes.csv', index=False)

print("Top 10 KO responsive genes have been saved to 'top10_KO_responsive_genes.csv'.")
# Out:
# Top 10 KO responsive genes have been saved to 'top10_KO_responsive_genes.csv'.

# %% [markdown]
# ## hyperparameter tuning

# %%
# Define the hyperparameters and ranges for grid search
hyperparams = {
    "epochs": 300,  # Increased epochs for more training
    "seed": 8096  # Trying a different seed
}

log_dir = None

# Define the range of learning rates and beta values to test
learning_rates = [1e-3, 1e-2, 5e-2, 1e-1, 5e-1]
beta_values = [1e-5, 5e-5, 1e-4, 5e-4, 1e-3]

# Function to train and evaluate the model, returning the ranked genes
def train_and_evaluate_return_genes(lr, beta):
    sensei = VGAE_trainer(
        data_wt,
        epochs=hyperparams["epochs"],
        lr=lr,
        log_dir=log_dir,
        beta=beta,
        seed=hyperparams["seed"],
        verbose=False,
    )
    sensei.train()

    z_mu_wt, z_std_wt = sensei.get_latent_vars(data_wt)
    z_mu_ko, z_std_ko = sensei.get_latent_vars(data_ko)
    dis = gk.utils.get_distance(z_mu_ko, z_std_ko, z_mu_wt, z_std_wt, by="KL")

    res_raw = utils.get_generank(data_wt, dis, rank=True)
    return res_raw

# Dictionary to store the results
results_genes = {}

# Loop over the range of learning rates and beta values
for lr in learning_rates:
    for beta in beta_values:
        res_raw = train_and_evaluate_return_genes(lr, beta)
        results_genes[(lr, beta)] = res_raw
        print(f"Learning Rate: {lr}, Beta: {beta}, Top Genes: \n{res_raw.head(10)}\n")

# After the loop, print all results for further inspection
for (lr, beta), res_raw in results_genes.items():
    print(f"\nLearning Rate: {lr}, Beta: {beta}")
    print(res_raw.head(10))
# Out:
# Learning Rate: 0.001, Beta: 1e-05, Top Genes:
#                  dis  rank
# Copb2   1.494926e-10     1
# Kctd12  1.480944e-10     2
# Col4a1  1.415956e-11     3
# Hba-a1  1.415068e-11     4
# Glra1   1.396661e-11     5
# Hbb-y   1.385714e-11     6
# Hba-a2  1.370548e-11     7
# Cxcl12  1.263256e-11     8
# Col1a2  1.096567e-11     9
# Col3a1  8.823609e-12    10
#
# Learning Rate: 0.001, Beta: 5e-05, Top Genes:
#                  dis  rank
# Copb2   1.494829e-10     1
# Kctd12  1.485732e-10     2
# Hba-a1  1.494249e-11     3
# Hbb-y   1.385914e-11     4
# Col4a1  1.375233e-11     5
# Glra1   1.344991e-11     6
# Hba-a2  1.306533e-11     7
# Cxcl12  1.210032e-11     8
# Col1a2  1.161449e-11     9
# Col3a1  8.730350e-12    10
#
# Learning Rate: 0.001, Beta: 0.0001, Top Genes:
#                  dis  rank
# Copb2   1.494904e-10     1
# Kctd12  1.491987e-10     2
# Col4a1  1.416645e-11     3
# Hba-a1  1.415024e-11     4
# Glra1   1.409339e-11     5
# Hbb-y   1.379252e-11     6
# Hba-a2  1.370482e-11     7
# Cxcl12  1.264233e-11     8
# Col1a2  1.147948e-11     9
# Col3a1  9.256595e-12    10
#
# Learning Rate: 0.001, Beta: 0.0005, Top Genes:
#                  dis  rank
# Kctd12  1.574645e-10     1
# Copb2   1.490998e-10     2
# Glra1   1.379608e-11     3
# Hba-a1  1.332645e-11     4
# Hbb-y   1.274625e-11     5
# Hba-a2  1.270184e-11     6
# Col4a1  1.242761e-11     7
# Cxcl12  1.074696e-11     8
# Col1a2  1.024913e-11     9
# Col3a1  8.811396e-12    10
#
# Learning Rate: 0.001, Beta: 0.001, Top Genes:
#                  dis  rank
# Kctd12  1.494640e-10     1
# Copb2   1.446623e-10     2
# Glra1   1.414024e-11     3
# Hba-a1  1.404743e-11     4
# Hbb-y   1.366285e-11     5
# Col4a1  1.358424e-11     6
# Hba-a2  1.317479e-11     7
# Cxcl12  1.210232e-11     8
# Col1a2  1.133538e-11     9
# Col3a1  9.373835e-12    10
#
# Learning Rate: 0.01, Beta: 1e-05, Top Genes:
#                  dis  rank
# Pitx1   3.417913e-08     1
# Hba-x   8.647099e-10     2
# Hba-a1  8.625352e-10     3
# Hba-a2  8.343417e-10     4
# Kctd12  1.202174e-10     5
# Col4a1  2.679390e-11     6
# Col1a2  2.508660e-11     7
# Hbb-y   2.125966e-11     8
# Col3a1  1.836953e-11     9
# Cxcl12  1.439315e-11    10
#
# Learning Rate: 0.01, Beta: 5e-05, Top Genes:
#                  dis  rank
# Pitx1   3.420182e-08     1
# Hba-a1  8.646988e-10     2
# Hba-x   8.641952e-10     3
# Hba-a2  8.386825e-10     4
# Kctd12  1.208078e-10     5
# Col4a1  2.677214e-11     6
# Col1a2  2.496225e-11     7
# Hbb-y   2.028666e-11     8
# Col3a1  1.854006e-11     9
# Myl4    1.359646e-11    10
#
# Learning Rate: 0.01, Beta: 0.0001, Top Genes:
#                  dis  rank
# Pitx1   3.445954e-08     1
# Hba-a1  9.107390e-10     2
# Hba-x   9.027779e-10     3
# Hba-a2  8.812524e-10     4
# Kctd12  1.200158e-10     5
# Col4a1  2.674572e-11     6
# Col1a2  2.441713e-11     7
# Hbb-y   1.933476e-11     8
# Col3a1  1.745093e-11     9
# Cxcl12  1.405387e-11    10
#
# Learning Rate: 0.01, Beta: 0.0005, Top Genes:
#                  dis  rank
# Pitx1   3.437054e-08     1
# Hba-a1  8.889169e-10     2
# Hba-x   8.855294e-10     3
# Hba-a2  8.679479e-10     4
# Kctd12  1.219738e-10     5
# Col4a1  2.805178e-11     6
# Col1a2  2.483524e-11     7
# Hbb-y   2.152878e-11     8
# Col3a1  1.818545e-11     9
# Cxcl12  1.424927e-11    10
#
# Learning Rate: 0.01, Beta: 0.001, Top Genes:
#                  dis  rank
# Pitx1   3.441631e-08     1
# Hba-x   9.035865e-10     2
# Hba-a1  9.009749e-10     3
# Hba-a2  8.750141e-10     4
# Hdac4   2.737337e-10     5
# Kctd12  1.221074e-10     6
# Col4a1  2.625611e-11     7
# Col1a2  2.520673e-11     8
# Hbb-y   2.198419e-11     9
# Col3a1  1.800116e-11    10
#
# Learning Rate: 0.05, Beta: 1e-05, Top Genes:
#                    dis  rank
# Six2     348539.779142     1
# Col3a1   117541.714707     2
# Hba-a2   115278.661449     3
# Hbb-y    106446.732377     4
# Hba-x     99824.742114     5
# Pak3      98585.190454     6
# Glra1     97527.397992     7
# Hbb-bh1   93432.961263     8
# Hba-a1    91113.252139     9
# Ednrb     89943.866356    10
#
# Learning Rate: 0.05, Beta: 5e-05, Top Genes:
#                 dis  rank
# Glra1   3504.248544     1
# Hoxd4   2599.771001     2
# Pak3    2359.031826     3
# Hoxa5   1636.387151     4
# Msx3    1442.513971     5
# Ednrb   1156.086585     6
# Pax3     858.625378     7
# Ptprz1   692.956348     8
# Lhx2     674.523749     9
# Hba-x    532.538283    10
#
# Learning Rate: 0.05, Beta: 0.0001, Top Genes:
#                    dis  rank
# Six2     374977.585988     1
# Col3a1     8652.828745     2
# Hba-a2     5649.671488     3
# Hbb-y      5276.064550     4
# Hba-a1     4970.662340     5
# Hba-x      4834.479136     6
# Hbb-bh1    4618.083816     7
# Glra1      4062.152232     8
# Fbn2       2864.114269     9
# Cnn2       2576.272493    10
#
# Learning Rate: 0.05, Beta: 0.0005, Top Genes:
#                 dis  rank
# Six2    8423.716324     1
# Col3a1    16.065773     2
# Col1a2     8.421597     3
# Vcan       6.678489     4
# Gpc3       6.598462     5
# Lgals1     5.790285     6
# Fbn2       5.741572     7
# Rbp1       5.733980     8
# Col4a1     5.731743     9
# Cxcl12     5.602060    10
#
# Learning Rate: 0.05, Beta: 0.001, Top Genes:
#               dis  rank
# Hoxd4    0.411197     1
# Six2     0.377455     2
# Glra1    0.307083     3
# Foxg1    0.096710     4
# Fabp7    0.086920     5
# Dtx4     0.080344     6
# Hba-x    0.052724     7
# Hba-a2   0.041673     8
# Hbb-bh1  0.039815     9
# Hbb-y    0.039558    10
#
# Learning Rate: 0.1, Beta: 1e-05, Top Genes:
#                   dis  rank
# Dpy19l1  3.042155e-01     1
# Foxg1    8.347415e-05     2
# Gpr89    4.781358e-05     3
# Col3a1   4.367734e-05     4
# Pitx1    5.109405e-06     5
# Kctd12   4.950605e-07     6
# Hba-a1   3.359927e-07     7
# Hba-a2   3.252360e-07     8
# Hba-x    1.422323e-07     9
# Col4a1   5.288797e-08    10
#
# Learning Rate: 0.1, Beta: 5e-05, Top Genes:
#                   dis  rank
# Six2     13846.320149     1
# Tagln        7.823785     2
# Sparc        5.486094     3
# Tgfbi        5.375524     4
# Col26a1      5.343307     5
# Foxp2        4.954372     6
# Foxc1        4.484856     7
# Vcan         4.229668     8
# Cxcl12       3.892971     9
# Col1a2       3.865877    10
#
# Learning Rate: 0.1, Beta: 0.0001, Top Genes:
#                   dis  rank
# Six2     11368.896847     1
# Sulf1        1.402153     2
# Igsf3        1.207820     3
# Arhgap1      1.140110     4
# Synpo        1.106606     5
# Tgfbi        1.092092     6
# Sparc        1.069306     7
# Pkdcc        1.063412     8
# Anxa2        1.043483     9
# Elk3         0.966740    10
#
# Learning Rate: 0.1, Beta: 0.0005, Top Genes:
#                  dis  rank
# Pitx1   1.296376e-06     1
# Hba-a1  7.258767e-08     2
# Hba-a2  7.028548e-08     3
# Kctd12  6.073108e-08     4
# Hba-x   3.982766e-08     5
# Col4a1  6.253208e-09     6
# Cxcl12  5.949891e-09     7
# Col1a2  5.796105e-09     8
# Hbb-y   4.552498e-09     9
# Col3a1  3.844083e-09    10
#
# Learning Rate: 0.1, Beta: 0.001, Top Genes:
#                   dis  rank
# Col3a1   1.000217e-05     1
# Stx16    8.059224e-06     2
# Pitx1    3.885900e-06     3
# Hba-a1   7.065741e-07     4
# Hba-a2   6.780440e-07     5
# Kctd12   5.134188e-07     6
# Hba-x    3.866013e-07     7
# Dpy19l1  1.747801e-07     8
# Foxg1    9.788261e-08     9
# Col4a1   6.218141e-08    10
# /usr/local/lib/python3.10/dist-packages/GenKI/utils.py:46: RuntimeWarning: invalid value encountered in scalar divide
#   np.linalg.det(S1) / np.linalg.det(S0)
# Learning Rate: 0.5, Beta: 1e-05, Top Genes:
#                   dis  rank
# Gm8292   2.371035e+15     1
# Six1     1.814306e+15     2
# Parm1    3.544818e+14     3
# Alx1     2.636548e+14     4
# Sparcl1  2.162101e+14     5
# Nfatc4   1.470254e+14     6
# Tes      4.851344e+13     7
# Frmd6    3.194389e+13     8
# Epcam    1.637800e+13     9
# Ptprz1   1.310082e+13    10
# /usr/local/lib/python3.10/dist-packages/GenKI/utils.py:46: RuntimeWarning: invalid value encountered in scalar divide
#   np.linalg.det(S1) / np.linalg.det(S0)
# Learning Rate: 0.5, Beta: 5e-05, Top Genes:
#                  dis  rank
# Pitx1   3.135530e-01     1
# Foxg1   1.174317e-04     2
# Gpr89   4.175294e-05     3
# Hba-a2  2.174939e-05     4
# Hba-a1  2.128475e-05     5
# Hba-x   1.758215e-05     6
# Kctd12  1.149878e-06     7
# Col4a1  1.056670e-06     8
# Cxcl12  9.809987e-07     9
# Col1a2  9.466198e-07    10
# /usr/local/lib/python3.10/dist-packages/GenKI/utils.py:46: RuntimeWarning: invalid value encountered in scalar divide
#   np.linalg.det(S1) / np.linalg.det(S0)
# Learning Rate: 0.5, Beta: 0.0001, Top Genes:
#                  dis  rank
# Pitx1   3.746639e+07     1
# Gap43   1.551276e+02     2
# Foxg1   1.219845e+01     3
# Hba-a1  9.216849e+00     4
# Hba-x   8.874584e+00     5
# Hba-a2  8.655033e+00     6
# Gpr89   8.032769e+00     7
# Hdac4   3.889166e+00     8
# Ttn     2.121481e+00     9
# Hbb-y   1.436997e+00    10
#
# Learning Rate: 0.5, Beta: 0.0005, Top Genes:
#               dis  rank
# Foxg1    0.000050     1
# Hdac4    0.000040     2
# Gm8292   0.000016     3
# Gm11263  0.000009     4
# Igfbp5   0.000009     5
# Myl3     0.000004     6
# Myh7     0.000003     7
# Myh6     0.000003     8
# Ttn      0.000003     9
# Hba-a1   0.000002    10
#
# Learning Rate: 0.5, Beta: 0.001, Top Genes:
#                   dis  rank
# Gpr89    4.654489e+14     1
# Mrpl57   6.581136e+10     2
# Gm11263  4.833268e-04     3
# Foxg1    3.461426e-04     4
# Dpy19l1  1.039465e-04     5
# Ttn      3.249073e-05     6
# Hdac4    2.382079e-05     7
# Col3a1   8.833726e-06     8
# Myl3     6.507684e-06     9
# Myh7     5.842495e-06    10
#
#
# Learning Rate: 0.001, Beta: 1e-05
#                  dis  rank
# Copb2   1.494926e-10     1
# Kctd12  1.480944e-10     2
# Col4a1  1.415956e-11     3
# Hba-a1  1.415068e-11     4
# Glra1   1.396661e-11     5
# Hbb-y   1.385714e-11     6
# Hba-a2  1.370548e-11     7
# Cxcl12  1.263256e-11     8
# Col1a2  1.096567e-11     9
# Col3a1  8.823609e-12    10
#
# Learning Rate: 0.001, Beta: 5e-05
#                  dis  rank
# Copb2   1.494829e-10     1
# Kctd12  1.485732e-10     2
# Hba-a1  1.494249e-11     3
# Hbb-y   1.385914e-11     4
# Col4a1  1.375233e-11     5
# Glra1   1.344991e-11     6
# Hba-a2  1.306533e-11     7
# Cxcl12  1.210032e-11     8
# Col1a2  1.161449e-11     9
# Col3a1  8.730350e-12    10
#
# Learning Rate: 0.001, Beta: 0.0001
#                  dis  rank
# Copb2   1.494904e-10     1
# Kctd12  1.491987e-10     2
# Col4a1  1.416645e-11     3
# Hba-a1  1.415024e-11     4
# Glra1   1.409339e-11     5
# Hbb-y   1.379252e-11     6
# Hba-a2  1.370482e-11     7
# Cxcl12  1.264233e-11     8
# Col1a2  1.147948e-11     9
# Col3a1  9.256595e-12    10
#
# Learning Rate: 0.001, Beta: 0.0005
#                  dis  rank
# Kctd12  1.574645e-10     1
# Copb2   1.490998e-10     2
# Glra1   1.379608e-11     3
# Hba-a1  1.332645e-11     4
# Hbb-y   1.274625e-11     5
# Hba-a2  1.270184e-11     6
# Col4a1  1.242761e-11     7
# Cxcl12  1.074696e-11     8
# Col1a2  1.024913e-11     9
# Col3a1  8.811396e-12    10
#
# Learning Rate: 0.001, Beta: 0.001
#                  dis  rank
# Kctd12  1.494640e-10     1
# Copb2   1.446623e-10     2
# Glra1   1.414024e-11     3
# Hba-a1  1.404743e-11     4
# Hbb-y   1.366285e-11     5
# Col4a1  1.358424e-11     6
# Hba-a2  1.317479e-11     7
# Cxcl12  1.210232e-11     8
# Col1a2  1.133538e-11     9
# Col3a1  9.373835e-12    10
#
# Learning Rate: 0.01, Beta: 1e-05
#                  dis  rank
# Pitx1   3.417913e-08     1
# Hba-x   8.647099e-10     2
# Hba-a1  8.625352e-10     3
# Hba-a2  8.343417e-10     4
# Kctd12  1.202174e-10     5
# Col4a1  2.679390e-11     6
# Col1a2  2.508660e-11     7
# Hbb-y   2.125966e-11     8
# Col3a1  1.836953e-11     9
# Cxcl12  1.439315e-11    10
#
# Learning Rate: 0.01, Beta: 5e-05
#                  dis  rank
# Pitx1   3.420182e-08     1
# Hba-a1  8.646988e-10     2
# Hba-x   8.641952e-10     3
# Hba-a2  8.386825e-10     4
# Kctd12  1.208078e-10     5
# Col4a1  2.677214e-11     6
# Col1a2  2.496225e-11     7
# Hbb-y   2.028666e-11     8
# Col3a1  1.854006e-11     9
# Myl4    1.359646e-11    10
#
# Learning Rate: 0.01, Beta: 0.0001
#                  dis  rank
# Pitx1   3.445954e-08     1
# Hba-a1  9.107390e-10     2
# Hba-x   9.027779e-10     3
# Hba-a2  8.812524e-10     4
# Kctd12  1.200158e-10     5
# Col4a1  2.674572e-11     6
# Col1a2  2.441713e-11     7
# Hbb-y   1.933476e-11     8
# Col3a1  1.745093e-11     9
# Cxcl12  1.405387e-11    10
#
# Learning Rate: 0.01, Beta: 0.0005
#                  dis  rank
# Pitx1   3.437054e-08     1
# Hba-a1  8.889169e-10     2
# Hba-x   8.855294e-10     3
# Hba-a2  8.679479e-10     4
# Kctd12  1.219738e-10     5
# Col4a1  2.805178e-11     6
# Col1a2  2.483524e-11     7
# Hbb-y   2.152878e-11     8
# Col3a1  1.818545e-11     9
# Cxcl12  1.424927e-11    10
#
# Learning Rate: 0.01, Beta: 0.001
#                  dis  rank
# Pitx1   3.441631e-08     1
# Hba-x   9.035865e-10     2
# Hba-a1  9.009749e-10     3
# Hba-a2  8.750141e-10     4
# Hdac4   2.737337e-10     5
# Kctd12  1.221074e-10     6
# Col4a1  2.625611e-11     7
# Col1a2  2.520673e-11     8
# Hbb-y   2.198419e-11     9
# Col3a1  1.800116e-11    10
#
# Learning Rate: 0.05, Beta: 1e-05
#                    dis  rank
# Six2     348539.779142     1
# Col3a1   117541.714707     2
# Hba-a2   115278.661449     3
# Hbb-y    106446.732377     4
# Hba-x     99824.742114     5
# Pak3      98585.190454     6
# Glra1     97527.397992     7
# Hbb-bh1   93432.961263     8
# Hba-a1    91113.252139     9
# Ednrb     89943.866356    10
#
# Learning Rate: 0.05, Beta: 5e-05
#                 dis  rank
# Glra1   3504.248544     1
# Hoxd4   2599.771001     2
# Pak3    2359.031826     3
# Hoxa5   1636.387151     4
# Msx3    1442.513971     5
# Ednrb   1156.086585     6
# Pax3     858.625378     7
# Ptprz1   692.956348     8
# Lhx2     674.523749     9
# Hba-x    532.538283    10
#
# Learning Rate: 0.05, Beta: 0.0001
#                    dis  rank
# Six2     374977.585988     1
# Col3a1     8652.828745     2
# Hba-a2     5649.671488     3
# Hbb-y      5276.064550     4
# Hba-a1     4970.662340     5
# Hba-x      4834.479136     6
# Hbb-bh1    4618.083816     7
# Glra1      4062.152232     8
# Fbn2       2864.114269     9
# Cnn2       2576.272493    10
#
# Learning Rate: 0.05, Beta: 0.0005
#                 dis  rank
# Six2    8423.716324     1
# Col3a1    16.065773     2
# Col1a2     8.421597     3
# Vcan       6.678489     4
# Gpc3       6.598462     5
# Lgals1     5.790285     6
# Fbn2       5.741572     7
# Rbp1       5.733980     8
# Col4a1     5.731743     9
# Cxcl12     5.602060    10
#
# Learning Rate: 0.05, Beta: 0.001
#               dis  rank
# Hoxd4    0.411197     1
# Six2     0.377455     2
# Glra1    0.307083     3
# Foxg1    0.096710     4
# Fabp7    0.086920     5
# Dtx4     0.080344     6
# Hba-x    0.052724     7
# Hba-a2   0.041673     8
# Hbb-bh1  0.039815     9
# Hbb-y    0.039558    10
#
# Learning Rate: 0.1, Beta: 1e-05
#                   dis  rank
# Dpy19l1  3.042155e-01     1
# Foxg1    8.347415e-05     2
# Gpr89    4.781358e-05     3
# Col3a1   4.367734e-05     4
# Pitx1    5.109405e-06     5
# Kctd12   4.950605e-07     6
# Hba-a1   3.359927e-07     7
# Hba-a2   3.252360e-07     8
# Hba-x    1.422323e-07     9
# Col4a1   5.288797e-08    10
#
# Learning Rate: 0.1, Beta: 5e-05
#                   dis  rank
# Six2     13846.320149     1
# Tagln        7.823785     2
# Sparc        5.486094     3
# Tgfbi        5.375524     4
# Col26a1      5.343307     5
# Foxp2        4.954372     6
# Foxc1        4.484856     7
# Vcan         4.229668     8
# Cxcl12       3.892971     9
# Col1a2       3.865877    10
#
# Learning Rate: 0.1, Beta: 0.0001
#                   dis  rank
# Six2     11368.896847     1
# Sulf1        1.402153     2
# Igsf3        1.207820     3
# Arhgap1      1.140110     4
# Synpo        1.106606     5
# Tgfbi        1.092092     6
# Sparc        1.069306     7
# Pkdcc        1.063412     8
# Anxa2        1.043483     9
# Elk3         0.966740    10
#
# Learning Rate: 0.1, Beta: 0.0005
#                  dis  rank
# Pitx1   1.296376e-06     1
# Hba-a1  7.258767e-08     2
# Hba-a2  7.028548e-08     3
# Kctd12  6.073108e-08     4
# Hba-x   3.982766e-08     5
# Col4a1  6.253208e-09     6
# Cxcl12  5.949891e-09     7
# Col1a2  5.796105e-09     8
# Hbb-y   4.552498e-09     9
# Col3a1  3.844083e-09    10
#
# Learning Rate: 0.1, Beta: 0.001
#                   dis  rank
# Col3a1   1.000217e-05     1
# Stx16    8.059224e-06     2
# Pitx1    3.885900e-06     3
# Hba-a1   7.065741e-07     4
# Hba-a2   6.780440e-07     5
# Kctd12   5.134188e-07     6
# Hba-x    3.866013e-07     7
# Dpy19l1  1.747801e-07     8
# Foxg1    9.788261e-08     9
# Col4a1   6.218141e-08    10
#
# Learning Rate: 0.5, Beta: 1e-05
#                   dis  rank
# Gm8292   2.371035e+15     1
# Six1     1.814306e+15     2
# Parm1    3.544818e+14     3
# Alx1     2.636548e+14     4
# Sparcl1  2.162101e+14     5
# Nfatc4   1.470254e+14     6
# Tes      4.851344e+13     7
# Frmd6    3.194389e+13     8
# Epcam    1.637800e+13     9
# Ptprz1   1.310082e+13    10
#
# Learning Rate: 0.5, Beta: 5e-05
#                  dis  rank
# Pitx1   3.135530e-01     1
# Foxg1   1.174317e-04     2
# Gpr89   4.175294e-05     3
# Hba-a2  2.174939e-05     4
# Hba-a1  2.128475e-05     5
# Hba-x   1.758215e-05     6
# Kctd12  1.149878e-06     7
# Col4a1  1.056670e-06     8
# Cxcl12  9.809987e-07     9
# Col1a2  9.466198e-07    10
#
# Learning Rate: 0.5, Beta: 0.0001
#                  dis  rank
# Pitx1   3.746639e+07     1
# Gap43   1.551276e+02     2
# Foxg1   1.219845e+01     3
# Hba-a1  9.216849e+00     4
# Hba-x   8.874584e+00     5
# Hba-a2  8.655033e+00     6
# Gpr89   8.032769e+00     7
# Hdac4   3.889166e+00     8
# Ttn     2.121481e+00     9
# Hbb-y   1.436997e+00    10
#
# Learning Rate: 0.5, Beta: 0.0005
#               dis  rank
# Foxg1    0.000050     1
# Hdac4    0.000040     2
# Gm8292   0.000016     3
# Gm11263  0.000009     4
# Igfbp5   0.000009     5
# Myl3     0.000004     6
# Myh7     0.000003     7
# Myh6     0.000003     8
# Ttn      0.000003     9
# Hba-a1   0.000002    10
#
# Learning Rate: 0.5, Beta: 0.001
#                   dis  rank
# Gpr89    4.654489e+14     1
# Mrpl57   6.581136e+10     2
# Gm11263  4.833268e-04     3
# Foxg1    3.461426e-04     4
# Dpy19l1  1.039465e-04     5
# Ttn      3.249073e-05     6
# Hdac4    2.382079e-05     7
# Col3a1   8.833726e-06     8
# Myl3     6.507684e-06     9
# Myh7     5.842495e-06    10
# /usr/local/lib/python3.10/dist-packages/GenKI/utils.py:46: RuntimeWarning: invalid value encountered in scalar divide
#   np.linalg.det(S1) / np.linalg.det(S0)

# %% [markdown]
# # SHAP value

# %%
import pandas as pd

# Load the data from CSV file
file_path = '/content/feature_feature_importance.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Define the list of genes of interest
gene_of_interest = 'Six2'
updated_genes_list = gene_of_interest + 'Col3a1', 'Col1a2', 'Vcan', 'Gpc3', 'Lgals1',	'Fbn2', 'Rbp1', 'Col4a1', 'Cxcl12'

# Filter data for the genes of interest
filtered_data = data[data['Source'].isin(updated_genes_list)]

# Separate data for RNA -> Niche and RNA -> Protein directions
rna_niche_data = filtered_data[filtered_data['Direction'] == 'RNA -> Niche']
rna_protein_data = filtered_data[filtered_data['Direction'] == 'RNA -> Protein']

# Find the top 3 unique RNA -> Niche and RNA -> Protein interactions with the highest 'Value'
top_rna_niche = rna_niche_data.sort_values(by='Value', ascending=False).drop_duplicates(subset=['Source', 'Target']).groupby('Source').head(3)
top_rna_protein = rna_protein_data.sort_values(by='Value', ascending=False).drop_duplicates(subset=['Source', 'Target']).groupby('Source').head(3)

# Identify cases where the 'Target' value is the same as the 'Source' value
rna_protein_duplicates = top_rna_protein[top_rna_protein['Target'] == top_rna_protein['Source']]
rna_niche_duplicates = top_rna_niche[top_rna_niche['Target'] == top_rna_niche['Source']]

# Remove duplicate entries from the original top lists
top_rna_protein_cleaned = top_rna_protein[~(top_rna_protein['Target'] == top_rna_protein['Source'])]
top_rna_niche_cleaned = top_rna_niche[~(top_rna_niche['Target'] == top_rna_niche['Source'])]

# Find the next highest entries for those with matching 'Target' and 'Source'
next_rna_protein = rna_protein_data[~rna_protein_data.isin(rna_protein_duplicates)].sort_values(by='Value', ascending=False)
next_rna_protein_add = next_rna_protein.groupby('Source').apply(lambda x: x[~x['Target'].isin(top_rna_protein_cleaned['Target'])].head(1)).reset_index(drop=True)

next_rna_niche = rna_niche_data[~rna_niche_data.isin(rna_niche_duplicates)].sort_values(by='Value', ascending=False)
next_rna_niche_add = next_rna_niche.groupby('Source').apply(lambda x: x[~x['Target'].isin(top_rna_niche_cleaned['Target'])].head(1)).reset_index(drop=True)

# Combine the original top lists with the added entries
final_top_rna_protein = pd.concat([top_rna_protein_cleaned, next_rna_protein_add]).sort_values(by=['Source', 'Value'], ascending=[True, False]).groupby('Source').head(3)
final_top_rna_niche = pd.concat([top_rna_niche_cleaned, next_rna_niche_add]).sort_values(by=['Source', 'Value'], ascending=[True, False]).groupby('Source').head(3)

# Combine all results into a single DataFrame
combined_df = pd.concat([final_top_rna_protein, final_top_rna_niche])

# Save the results to a single sheet in an Excel file
output_path = f'./Top_RNA_Niche_Protein_Interactions_Single_Sheet_{gene_of_interest}.xlsx'  # Replace with your desired output path

with pd.ExcelWriter(output_path) as writer:
    combined_df.to_excel(writer, sheet_name='Top Interactions', index=False)

print(f"Results have been saved to {output_path}")
# Out:
# <ipython-input-2-6b7f4c6bab7a>:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   next_rna_protein_add = next_rna_protein.groupby('Source').apply(lambda x: x[~x['Target'].isin(top_rna_protein_cleaned['Target'])].head(1)).reset_index(drop=True)
# <ipython-input-2-6b7f4c6bab7a>:35: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   next_rna_niche_add = next_rna_niche.groupby('Source').apply(lambda x: x[~x['Target'].isin(top_rna_niche_cleaned['Target'])].head(1)).reset_index(drop=True)
# Results have been saved to ./Top_RNA_Niche_Protein_Interactions_Single_Sheet_Six2.xlsx
